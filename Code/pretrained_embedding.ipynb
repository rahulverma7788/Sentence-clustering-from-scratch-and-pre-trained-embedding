# %% [markdown]
# ### Importing the library and loading the file

# %%
# !pip install autoreload

# %%
# %matplotlib inline
from random import randint
import numpy as np
import torch
import shutil
import string
import nltk.data
import pandas as pd
import pickle

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
corpus = pd.read_csv("/content/preprocessed_data")
corpus.drop(corpus.filter(regex="Unnamed"),axis=1, inplace=True)

# %%
corpus = corpus[:20000]
corpus['Text'] = corpus['Text'].replace(np.nan, '')
corpus.head(3)
# Out:
#                                                 Text
# 0  moeller student run newspaper the crusader con...
# 1  in the crusader first place second highest hon...
# 2  the squire student literary journal features s...

# %%
training_data = corpus["Text"]
training_data = list(training_data)

# %% [markdown]
# ### Loading infersent model and embedding

# %%
model_version = 1
MODEL_PATH = "/content/gdrive/MyDrive/infersent1.pkl" 
W2V_PATH = '/content/gdrive/MyDrive/glove.840B.300d.txt'
VOCAB_SIZE = 1e5

# %%
from models import InferSent
params_model = {'bsize': 64, 'word_emb_dim': 300, 'enc_lstm_dim': 2048,
                'pool_type': 'max', 'dpout_model': 0.0, 'version': model_version}
model = InferSent(params_model)
model.load_state_dict(torch.load(MODEL_PATH))
# Out:
# <All keys matched successfully>

# %%
model.set_w2v_path(W2V_PATH)
model.build_vocab_k_words(K=VOCAB_SIZE)
# Out:
# Vocab size : 100000.0

# %%
#embeddings = model.encode(training_data, bsize=128, tokenize=False, verbose=True)
#print('nb sentences encoded : {0}'.format(len(embeddings)))

# %%
#with open('infersent_sentence_embeddings.pickle', 'wb') as handle:
#    pickle.dump(embeddings, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('/content/gdrive/MyDrive/infersent_sentence_embeddings.pickle', 'rb') as handle:
    embeddings = pickle.load(handle)

# %%
#embeddings

# %% [markdown]
# ### Clustering using the threshold value

# %%
import torch
from torch import Tensor, device

# %%
def cos_sim(a: Tensor, b: Tensor):
    if not isinstance(a, torch.Tensor):
        a = torch.tensor(a)
    if not isinstance(b, torch.Tensor):
        b = torch.tensor(b)
    if len(a.shape) == 1:
        a = a.unsqueeze(0)
    if len(b.shape) == 1:
        b = b.unsqueeze(0)
    a_norm = torch.nn.functional.normalize(a, p=2, dim=1)
    b_norm = torch.nn.functional.normalize(b, p=2, dim=1)
    return torch.mm(a_norm, b_norm.transpose(0, 1))

# %%
def cluster_detection(embeddings, threshold, min_community_size, batch_size=32):
    if not isinstance(embeddings, torch.Tensor):
        embeddings = torch.tensor(embeddings)
    threshold = torch.tensor(threshold, device=embeddings.device)
    extracted_communities = []
    min_community_size = min(min_community_size, len(embeddings))
    sort_max_size = min(max(2 * min_community_size, 50), len(embeddings))
    for start_idx in range(0, len(embeddings), batch_size):
        cos_scores = cos_sim(embeddings[start_idx:start_idx + batch_size], embeddings)
        top_k_values, _ = cos_scores.topk(k=min_community_size, largest=True)
        for i in range(len(top_k_values)):
            if top_k_values[i][-1] >= threshold:
                new_cluster = []
                top_val_large, top_idx_large = cos_scores[i].topk(k=sort_max_size, largest=True)
                while top_val_large[-1] > threshold and sort_max_size < len(embeddings):
                    sort_max_size = min(2 * sort_max_size, len(embeddings))
                    top_val_large, top_idx_large = cos_scores[i].topk(k=sort_max_size, largest=True)
                for idx, val in zip(top_idx_large.tolist(), top_val_large):
                    if val < threshold:
                        break
                    new_cluster.append(idx)
                extracted_communities.append(new_cluster)
        del cos_scores
    extracted_communities = sorted(extracted_communities, key=lambda x: len(x), reverse=True)
    unique_communities = []
    extracted_ids = set()
    for cluster_id, community in enumerate(extracted_communities):
        community = sorted(community)
        non_overlapped_community = []
        for idx in community:
            if idx not in extracted_ids:
                non_overlapped_community.append(idx)
        if len(non_overlapped_community) >= min_community_size:
            unique_communities.append(non_overlapped_community)
            extracted_ids.update(non_overlapped_community)
    unique_communities = sorted(unique_communities, key=lambda x: len(x), reverse=True)
    return unique_communities

# %%
clusters = cluster_detection(embeddings, min_community_size=5, threshold=0.65)

# %% [markdown]
# ### Results of clustering

# %%
for i, cluster in enumerate(clusters):
    print("\nCluster {}, #{} Elements ".format(i+1, len(cluster)))
    for sentence_id in cluster[0:3]:
        print("\t", training_data[sentence_id])
# Out:
# Cluster 1, #11082 Elements
# 	 moeller student run newspaper the crusader consistently recognized one top region
# 	 in the crusader first place second highest honor high school newspaper receive american scholastic press association ref
# 	 the squire student literary journal features stories poems essays written moeller students
#
# Cluster 2, #1064 Elements
# 	 tony hunter professional football player buffalo bills los angeles rams
# 	 jack norris president co founder vegan outreach
# 	 in government sector the leakage government sector provides collection revenue taxes t provided households firms government
#
# Cluster 3, #336 Elements
# 	 measurement national income national income estimation aggregation economic activity circular flow
# 	 households spend income y goods services consumption c
# 	 real flow exchange goods services household firms whereas money flow monetary exchange two sectors
#
# Cluster 4, #313 Elements
# 	 knowledge interdependence circular flow income signifies interdependence activity upon one another
# 	 y e o this means expenditure buyers households becomes income sellers firms
# 	 when goods services flow one sector economy another known real flow
#
# Cluster 5, #179 Elements
# 	 piezoelectric detection cantilevers made quartz ref qplus configuration piezoelectric materials directly detect deflection electrical signal
# 	 it noted despite nomenclature repulsive contact occur avoided amplitude modulation afm frequency modulation afm depending settings
# 	 in amplitude modulation changes oscillation amplitude phase provide feedback signal imaging
#
# Cluster 6, #174 Elements
# 	 the return den years took conflict two families another level
# 	 in economy floundered gdp declined impact accelerated rising inflation failure political leadership
# 	 after births children victoria eugenie relationship alfonso deteriorated numerous affairs
#
# Cluster 7, #163 Elements
# 	 moeller high school opened doors september along la salle high school fellow cincinnati archdiocesan school
# 	 the first concert sydney musica viva presented verbrugghen hall sydney conservatorium music december
# 	 words three syllables compounds mostly loanwords usually derived pali sanskrit recently french
#
# Cluster 8, #96 Elements
# 	 all output o produced firms purchased households expenditure e
# 	 the land occupied mollie community located intersection blackford county roads north east farmland owned privately
# 	 in general courts consolidated funding state courts state biennial budget
#
# Cluster 9, #90 Elements
# 	 the sydney season featured goldner quartet piers lane james crabb
# 	 victoria eugenie great grandson felipe vi present king spain
# 	 norman alexander best leader southampton city council
#
# Cluster 10, #70 Elements
# 	 starting freshman class moeller high school adopted new laptop program
# 	 the standard us keyboard heavy clunky featured keys weighed approximately pounds
# 	 outside comic books boom tubes seen number occasions
#
# Cluster 11, #68 Elements
# 	 in shipments plasma tvs reached million units globally ref
# 	 the act allowed increases rent mortgage interest maximum six one half per cent
# 	 the default catalog called systemindex stores properties indexed items predefined naming pattern
#
# Cluster 12, #59 Elements
# 	 lorde defines racism sexism ageism heterosexism elitism classism altogether explains ism idea privileged superior right govern anything else
# 	 lorde work black feminism continues examined scholars today
# 	 a minor syllable unstressed syllable preceding main syllable word structure cv crv cvn crvn c consonant v vowel n nasal consonant
#
# Cluster 13, #56 Elements
# 	 it possible sue crown uk breach contract
# 	 misrepresentation means false statement fact made one party another party effect inducing party contract
# 	 according gordon v selico possible misrepresent either words conduct
#
# Cluster 14, #55 Elements
# 	 paul keels play play announcer ohio state university football basketball wbns fm
# 	 on december frank sinatra jr kidnapped ref
# 	 thor arrives tells loki silent threatens rip loki head body hammer
#
# Cluster 15, #54 Elements
# 	 audre lorde criticism feminists identified issues race class age gender sexuality
# 	 lorde actively strived change culture within feminist community implementing womanist ideology
# 	 in system announced support distributed data management architecture ddm
#
# Cluster 16, #54 Elements
# 	 capacitive detection metal coated cantilevers form capacitor another contact located behind cantilever ref
# 	 measures taken government lower inflation largely wiped natural disaster
# 	 the fuel price directly linked oil price thus subject potentially large fluctuations
#
# Cluster 17, #52 Elements
# 	 laurice guillen award winning film director actress also wife actor johnny delgado deceased
# 	 seth go khe member player pilipinas aguilas national tackle football team
# 	 air vice marshal michael william patrick knight
#
# Cluster 18, #49 Elements
# 	 the circular flow diagram abstraction economy whole
# 	 a disadvantage afm compared scanning electron microscope sem single scan image size
# 	 the afm consists cantilever sharp tip probe end used scan specimen surface
#
# Cluster 19, #42 Elements
# 	 may view economic organization system prize relations
# 	 other contributors mollie demise concerned jacob burnworth tile factory
# 	 mapics manufacturing production information control system popular s application
#
# Cluster 20, #39 Elements
# 	 there may circumstances would unjust permit defaulting party simply buy injured party damages
# 	 a mistake incorrect understanding one parties contract may used grounds invalidate agreement
# 	 if terms contract uncertain incomplete parties cannot reached agreement eyes law ref
#
# Cluster 21, #36 Elements
# 	 wallace emilie walker dunsandel chairman ellesmere county council
# 	 senior chaplain venerable archdeacon walter thomas wheeldon
# 	 daniel philip mcelligott hawker australian capital territory
#
# Cluster 22, #33 Elements
# 	 on rainy day ramadhir singh overhears shahid ambitions taking coal mines
# 	 on august invited green performed stand comedy gathering juggalos
# 	 on august green appeared america got talent
#
# Cluster 23, #33 Elements
# 	 fernando henrique cardoso started first term january reelected
# 	 despite initial decrease inflation returned higher economic plans achieving month
# 	 hungary defeat england budapest next year still england record defeat
#
# Cluster 24, #31 Elements
# 	 may ships arrive first collection point cape verde
# 	 william mckeown auxiliary constable northern ireland airports constabulary
# 	 kenneth quine driver rushen emergency ambulance service port erin isle man
#
# Cluster 25, #30 Elements
# 	 dr arthur ashley cooper pymble new south wales
# 	 norman alfred coleman lilli pilli new south wales
# 	 william john raper miranda new south wales
#
# Cluster 26, #29 Elements
# 	 these phasing arrangements required careful scrutiny cost providing services assessment value services
# 	 at core xps print path xpsdrv xps based printer driver includes filter pipeline
# 	 process creation overhead reduced significant improvements dll address resolving schemes
#
# Cluster 27, #29 Elements
# 	 when train arrives pine tree snowflake sight chances falling appear dim
# 	 gloucester saw stone bottle throwing morning order quickly restored ref
# 	 erik weihenmayer first blind person reach summit mount everest ref
#
# Cluster 28, #28 Elements
# 	 regorafenib stivarga fda approved advanced gists cannot surgically removed longer respond imatinib gleevec sunitinib sutent ref
# 	 deafness hearing impairment partial total inability hear ability would usually expected
# 	 many types glider aircraft designed exploit rising air therefore also soar
#
# Cluster 29, #28 Elements
# 	 an open score score polyphonic piece showing voice separate staff
# 	 there households children age living headed married couples living together female householder husband present non families
# 	 engineering students ufe prepare master degree paris vi university
#
# Cluster 30, #27 Elements
# 	 lorde poetry became open personal grew older became confident sexuality
# 	 much rexroth work classified erotic love poetry given deep fascination transcendent love
# 	 body proportions human anime characters tend accurately reflect proportions human body reality
#
# Cluster 31, #25 Elements
# 	 autism false prophets written vaccine expert paul offit
# 	 wonder woman feline nemesis would go join legion doom
# 	 graeme monocle makes people see illusions break order super friends january
#
# Cluster 32, #25 Elements
# 	 mollie considered part east central indiana northern indiana
# 	 as regional commercial economic hub port masao butuan seaport
# 	 descartes rejects teleological purposive view material world dominant west time aristotle
#
# Cluster 33, #25 Elements
# 	 squadron leader geoffrey hector williams royal air force
# 	 squadron leader malcolm stanley bartlett royal air force
# 	 donald hardwick chairman steel division johnson firth brown ltd
#
# Cluster 34, #25 Elements
# 	 george tuoro marsden hamilton
# 	 eugene james metge macloughlin te puke
# 	 donald murray stafford rotorua
#
# Cluster 35, #24 Elements
# 	 captain eirianydd jones lane cove new south wales
# 	 councillor eric hodgson woods tomingley new south wales
# 	 berek robert segan north ivanhoe
#
# Cluster 36, #23 Elements
# 	 there households children age living married couples living together female householder husband present non families
# 	 children teenagers years old make population adults years old make seniors years old make ref
# 	 there households children age living married couples living together female householder husband present non families
#
# Cluster 37, #22 Elements
# 	 due nature afm probes cannot normally measure steep walls overhangs
# 	 to recover damages claimant must show breach contract caused foreseeable loss ref
# 	 no significant differences habitat use genders observed arizona ref
#
# Cluster 38, #22 Elements
# 	 princess beatrice daughter arrived biarritz january stayed villa mauriscot days later king alfonso met
# 	 trudy stevens provided singing voice vera ellen except sisters rosemary clooney sang parts
# 	 bell retired returned coast coast am several times
#
# Cluster 39, #22 Elements
# 	 windows vista service pack later built support exfat ref
# 	 for next five years fisher held number jobs
# 	 wdml fm radio station adult rock roll format mhz
#
# Cluster 40, #22 Elements
# 	 frederick eady coull warden sands forvie national nature reserve nature conservancy council
# 	 the downtown shopping business district morristown centered around square park known morristown green
# 	 enfield town centre enfield town park alleyways palace garden shopping centre guarded police
#
# Cluster 41, #22 Elements
# 	 in mollie population people community consisted two houses
# 	 as census people households families residing town
# 	 in town population spread age years age older
#
# Cluster 42, #21 Elements
# 	 hungary opening game south korea kocsis scoring hat trick
# 	 a year old man brixton trevor ellis shot killed south croydon warrington road ref
# 	 donovan member usa national team world championships held sao paulo brazil
#
# Cluster 43, #21 Elements
# 	 victoria eugenie devoted work hospitals services poor well education
# 	 butuan city commercial industrial administrative center caraga region ref
# 	 kathleen hilda little lately home help birmingham city council
#
# Cluster 44, #21 Elements
# 	 professor george lancelot rolleston dean the christchurch clinical school university otago
# 	 the ostau bearn pau organization bringing together practice teach language ref
# 	 in shippensburg area school district students took sat exams
#
# Cluster 45, #21 Elements
# 	 major local lieutenant colonel gavin horsburgh peebles gordon highlanders
# 	 major quartermaster thomas raymond major forrest coldstream guards
# 	 major terence thomas taylor the royal anglian regiment
#
# Cluster 46, #21 Elements
# 	 february the th armada arrives malindi
# 	 michael edward howell charge d affaires hm embassy kabul
# 	 flight lieutenant julian michael leigh
#
# Cluster 47, #20 Elements
# 	 chadda revealed interview role helped bag film roles ref
# 	 the special organisation played key role armenian genocide
# 	 his knighthood services military healthcare psychological medicine ref
#
# Cluster 48, #20 Elements
# 	 successive chilean governments actively pursued trade liberalizing agreements
# 	 however concerned state government may notification apply provisions areas
# 	 bcs conducts bcs higher education qualifications many countries
#
# Cluster 49, #20 Elements
# 	 womanism existence naturally opens various definitions interpretations
# 	 this ordering objects changed meaning clarified inclusion particles
# 	 thomas hobbes worked previous notions conatus principle
#
# Cluster 50, #20 Elements
# 	 william alexander sutton christchurch
# 	 alan raine topham auckland
# 	 richard john hadlee christchurch
#
# Cluster 51, #20 Elements
# 	 butuan city land area ref roughly total area caraga region
# 	 the capital canton aarau located western border aare
# 	 the town served u s highways interstate
#
# Cluster 52, #20 Elements
# 	 sergeant peter stanley burton w
# 	 flight sergeant gary david bydder a
# 	 sergeant david keith russell a
#
# Cluster 53, #19 Elements
# 	 the initial reactors kellogg lurgi gasifiers tricky expensive operate
# 	 a convention signed ufe ministry oil mars
# 	 nellie cumberbatch lately storekeeper royal ordnance factory chorley ministry defence
#
# Cluster 54, #19 Elements
# 	 early season coveleski pitched straight scoreless innings winning three consecutive games time ref
# 	 coveleski wins losses era games starts year career
# 	 at end six month trial period club attracted members
#
# Cluster 55, #18 Elements
# 	 mollie located intersection county roads north east
# 	 harold martin ford casuarina northern territory
# 	 archibald mckinnon mathieson countryside ranger east lothian district council
#
# Cluster 56, #18 Elements
# 	 ronald george russell mayor wanganui
# 	 arthur william shepherd mackay queensland
# 	 roger robert woodward london england
#
# Cluster 57, #17 Elements
# 	 barbara critten hamilton victoria
# 	 virgilio emmanuel zammit regents park new south wales
# 	 edith joyce bradbury dining room supervisor derby lonsdale college higher education
#
# Cluster 58, #17 Elements
# 	 in brazil home refugees different nationalities
# 	 as census ref people households families residing city
# 	 as census ref people households families residing city
#
# Cluster 59, #17 Elements
# 	 gordon mcdowall clerical officer department education science
# 	 the methodist school morragh applied become national school
# 	 the school district adjusted index shippensburg area school district ref
#
# Cluster 60, #17 Elements
# 	 the chapel ch teau de pau visible main entrance adjacent brick keep
# 	 its small garden tended marie antoinette spent summers city
# 	 parc beaumont lake river waterfall many flower beds large rockery rose garden
#
# Cluster 61, #17 Elements
# 	 alan fleming gilkison wanaka
# 	 maurice raymond duckmanton christchurch
# 	 alan charlton fraser rangiora
#
# Cluster 62, #16 Elements
# 	 in wessely elected president royal college psychiatrists
# 	 while s paulo italians predominated city rio de janeiro portuguese remained main group
# 	 the ipstones family prominent affairs staffordshire held blymhill cuttlestone hundred time ref
#
# Cluster 63, #16 Elements
# 	 matron mary louisa pike corke pelaw main new south wales
# 	 william edgar district community physician west berkshire
# 	 john frost headmaster sullivan upper school holywood county down
#
# Cluster 64, #16 Elements
# 	 a panel plasma display typically comprises millions tiny compartments two panels glass
# 	 plasma screens made glass this may causes glare reflected objects viewing area
# 	 hair anime often unnaturally lively colorful uniquely styled
#
# Cluster 65, #16 Elements
# 	 sir francis scott mcfadzean chairman rolls royce ltd
# 	 edward anthony john alment president royal college obstetricians gynaecologists
# 	 joseph franklin madders braithwaite chairman baker perkins holdings ltd
#
# Cluster 66, #16 Elements
# 	 on august government shuttered parliament
# 	 count jacqueline michelle mcdonell ref last seen january
# 	 count inga monique hall ref last seen february
#
# Cluster 67, #16 Elements
# 	 irene mary reid ngakawau westport
# 	 dr laurel jean macintosh yeerongpilly queensland
# 	 desmond vincent o leary toorak victoria
#
# Cluster 68, #16 Elements
# 	 sheilah maureen winn christchurch
# 	 ailsa evelyn densem christchurch
# 	 thelma elsie pearson blenheim
#
# Cluster 69, #15 Elements
# 	 the hungarians arrived summer olympics unbeaten two years
# 	 the race saw ren dreyfus delahaye sensationally beating mercedes benz team
# 	 the red sox finished th year winning world series
#
# Cluster 70, #15 Elements
# 	 taha hussein egyptian writer intellectual became blind age three
# 	 the abbey community augustinian canons regular conventual canons technically monks
# 	 there references cantabria cantabri surviving greek latin texts
#
# Cluster 71, #15 Elements
# 	 peter john harrop deputy secretary cabinet office
# 	 anne elisabeth mueller robertson deputy secretary department industry
# 	 james patton davidson chairman clyde port authority
#
# Cluster 72, #14 Elements
# 	 contrary audre lorde open sexuality sexual awakening
# 	 social alienation estrangement division distancing people people important meaningful person sense self
# 	 some theories civil disobedience hold civil disobedience justified governmental entities
#
# Cluster 73, #14 Elements
# 	 chile second largest producer salmon world ref
# 	 the type display normally located radio operator station navigator
# 	 kmyr adult contemporary station licensed ames operated des moines
#
# Cluster 74, #14 Elements
# 	 when horacio returns argentina greeted old friend manolo nicknamed traveler wife talita
# 	 eoin o sullivan blind basketball player american football player coach ref
# 	 donovan recruited female player nation going college ref
#
# Cluster 75, #14 Elements
# 	 giganta appears challenge super friends voiced ruth forman
# 	 eventually murdoch learns name finds wife named emma jennifer connelly
# 	 dreadmon mutant red wolf deceased ally ninja turtles
#
# Cluster 76, #14 Elements
# 	 diana seach english specialist special education
# 	 roy lionel helmore principal cambridgeshire college arts technology
# 	 colin smith deputy head teacher wensleydale middle school blyth
#
# Cluster 77, #14 Elements
# 	 being regional center caraga butuan also region center education
# 	 olwen williams area nurse surrey area health authority
# 	 prallsville unincorporated community located along border delaware township
#
# Cluster 78, #14 Elements
# 	 the processors front panel display four hexadecimal leds
# 	 spool acronym simultaneous peripheral operations on line
# 	 a new user mode driver model called user mode driver framework
#
# Cluster 79, #13 Elements
# 	 she attended hunter college high school secondary school intellectually gifted students graduated
# 	 in october presidential elections fernando henrique cardoso elected votes
# 	 between bolivian immigrants come brazil every month looking job
#
# Cluster 80, #13 Elements
# 	 william john richard dawson foreign commonwealth office
# 	 thomas robert barron member british railways board
# 	 john albert parker foreign commonwealth office
#
# Cluster 81, #13 Elements
# 	 thomas nast caricaturist editorial cartoonist lived morristown years ref
# 	 the palais beaumont originally referred palais hiver winter palace created end th century
# 	 the modern discovery babylonia assyria begins excavations nineveh revealed library ashurbanipal
#
# Cluster 82, #13 Elements
# 	 modern khmer isolating language means uses little productive morphology
# 	 pau also green city occupied green areas many rare exotic species
# 	 being small minority usually leads functional bilingualism
#
# Cluster 83, #13 Elements
# 	 an afm probe sharp tip free swinging end cantilever protruding holder ref
# 	 a balloon bag filled gas lower density surrounding air provide buoyancy
# 	 a balloon may tethered like kite drift wind free flight
#
# Cluster 84, #13 Elements
# 	 plasma displays generally heavier lcd may require careful handling kept upright
# 	 readyboot uses ram cache optimize boot process system mb memory
# 	 gliding flight requires initial launch giving object enough energy fly
#
# Cluster 85, #13 Elements
# 	 ct scanning often undertaken see radiology section
# 	 unit testing provides sort living documentation system
# 	 unit testing also critical concept emergent design
#
# Cluster 86, #13 Elements
# 	 at beginning season spitball banned major league baseball
# 	 usc women water polo team began play head coach jovan vavic
# 	 guildford cricket club play home matches woodbridge road ground
#
# Cluster 87, #13 Elements
# 	 peter meinertzhagen general manager commonwealth development corporation
# 	 william alexander allen senior partner bickerdike allen partners
# 	 gordon frederick hendry assistant secretary scottish office
#
# Cluster 88, #13 Elements
# 	 in reduced serum assay cells assayed exploiting changes cell serum requirements
# 	 the herpesviruses kaposi sarcoma associated herpesvirus epstein barr virus believed cause cancer humans kaposi sarcoma burkitt lymphoma nasopharyngeal carcinoma
# 	 the retroviruses include t cell leukemia virus type i hiv rous sarcoma virus rsv
#
# Cluster 89, #13 Elements
# 	 flight sergeant brian charles clayton a
# 	 lieutenant colonel william edward rous coldstream guards
# 	 wing commander kenneth john ryan
#
# Cluster 90, #12 Elements
# 	 joyce iris kathleen norris head common services basildon district council
# 	 gordon francis goddard youth leader moor lane youth centre york
# 	 jyles tucker born linebacker san diego chargers ref
#
# Cluster 91, #12 Elements
# 	 in legislature established two courts take place existing supreme court
# 	 geoffrey arthur pyman principal administrative officer essex county council
# 	 daniel spader voorhees new jersey state treasurer ref
#
# Cluster 92, #12 Elements
# 	 the pound bell taken top southern pacific locomotive
# 	 the sisserou parrot amazona imperialis dominica national bird endemic mountain forests
# 	 dominica mostly volcanic beaches therefore tourism developed slowly neighbouring islands
#
# Cluster 93, #12 Elements
# 	 the type musical notation varies great deal genre style music
# 	 anime genre classification different types animation lend simple identity
# 	 within film number soon famous performers appear
#
# Cluster 94, #12 Elements
# 	 lyle edgar baker tumut new south wales
# 	 arnold newhouse bellevue hill new south wales
# 	 edward websdale painter unley park south australia
#
# Cluster 95, #12 Elements
# 	 jenny mccarthy magazine later named playmate year
# 	 the show also eight gemini award nominations
# 	 in australia first three series released
#
# Cluster 96, #12 Elements
# 	 philip manning dowson senior partner ove arup partnership
# 	 hugh reginald braden assistant secretary ministry defence
# 	 cecil herbert william hodges assistant secretary hm treasury
#
# Cluster 97, #12 Elements
# 	 contractual terms classified differently depending upon context jurisdiction
# 	 a core concept geobiology life changes time evolution
# 	 it common aiga number matai titles however one particular title important serve main matai title
#
# Cluster 98, #12 Elements
# 	 yolande elizabeth lyell gay hamilton
# 	 lorna margaret johnston auckland
# 	 margaret clare boyce auckland
#
# Cluster 99, #11 Elements
# 	 lorde died liver cancer november st croix living gloria i
# 	 rabbi dr alfred fabian killara new south wales
# 	 sergeant meherman tamang th duke edinburgh own gurkha rifles
#
# Cluster 100, #11 Elements
# 	 malignancy characterized local invasion metastases usually liver omentum peritoneum
# 	 lilleshall one small number monasteries england belonging rigorist arrouaisian branch augustinians
# 	 aarhus unusually high number parks covering total area around ref
#
# Cluster 101, #11 Elements
# 	 intonation often conveys semantic context khmer distinguishing declarative statements questions exclamations
# 	 complex sentences formed khmer addition one clauses main clause
# 	 iv read write portuguese language considering conditions naturalizing
#
# Cluster 102, #11 Elements
# 	 the voiceless plosives may occur without aspiration vs etc difference contrastive vowel
# 	 imatinib approved metastatic unresectable gist us fda february
# 	 in doctors diagnosed montana narrow spinal cavity
#
# Cluster 103, #11 Elements
# 	 he first major role millions air ref
# 	 reginald clarke shift electrician assistant sandbach works bp chemicals
# 	 the pharmaceutical sector growing represented pierre fabre boiron sanofi finorga companies
#
# Cluster 104, #11 Elements
# 	 a collection songs given musical usually printed label vocal selections
# 	 the band first album tender years became major hit album
# 	 the orchestre de chambre de lausanne lausanne opera ensemble vocal de lausanne provide diverse rich musical life
#
# Cluster 105, #11 Elements
# 	 mercury content tuna vary widely
# 	 also unlike fish white flesh muscle tissue tuna ranges pink dark red
# 	 juicing juice therapy practice consuming juice made raw fruit vegetables
#
# Cluster 106, #11 Elements
# 	 at columbia the first time one first films frank tashlin
# 	 a friendly match arranged november england
# 	 the movie made broadcast premiere ctv december
#
# Cluster 107, #11 Elements
# 	 the forestland mentioned earlier comprised production protection forest
# 	 depending virus variety genetic changes occur host cell
# 	 an ideal inductor would resistance energy losses
#
# Cluster 108, #11 Elements
# 	 titanus evil mutant future
# 	 before th century wilderness viewed desolate forbidding
# 	 satan primary motivation seems vengeance god cast heaven
#
# Cluster 109, #11 Elements
# 	 mutations exons rarely c kit gene known occur gist
# 	 a short score reduction work many instruments staves
# 	 wessely also long standing interest normal people react adversity responses appropriate
#
# Cluster 110, #11 Elements
# 	 the median income household borough median income family
# 	 the median income household city median income family
# 	 the median income household city median income family
#
# Cluster 111, #11 Elements
# 	 q deletion syndrome also known phelan mcdermid syndrome genetic disorder caused microdeletion chromosome
# 	 gluten free casein free diet diet eliminates dietary intake gluten casein
# 	 secretin hormone controls secretions duodenum also separately water homeostasis throughout body
#
# Cluster 112, #11 Elements
# 	 squadron leader michael anthony lavercombe
# 	 sir michael wilford hm ambassador tokyo
# 	 squadron leader robert charles tompkins
#
# Cluster 113, #11 Elements
# 	 warrant officer brian kelvin read v
# 	 petty officer douglas albert sheaff a
# 	 lieutenant colonel joseph brian mylchreest
#
# Cluster 114, #11 Elements
# 	 john oswald sanders auckland
# 	 thomas richard alexander mccleary christchurch
# 	 arthur john powe penguin tasmania
#
# Cluster 115, #11 Elements
# 	 piyush mishra tigmanshu dhulia given discretion decide among would perform roles nasir ramadhir
# 	 compensatory damages given party detrimented breach contract
# 	 in certain circumstances implied contract may created
#
# Cluster 116, #11 Elements
# 	 nancy elizabeth russell hawera
# 	 ralph james iorns golden bay
# 	 cecilia joan andrews greenwood havelock north
#
# Cluster 117, #11 Elements
# 	 the afm operated number modes depending application
# 	 several types interaction detected
# 	 lexical categories hard define khmer ref
#
# Cluster 118, #10 Elements
# 	 he one leads comedy one night tropics film introduced abbott costello
# 	 joan patricia gortley brighton le sands new south wales
# 	 on january five red lights spotted morristown area night skies
#
# Cluster 119, #10 Elements
# 	 this meant composers depend solely patronage wealthy aristocrats
# 	 however later times reward athlete rewarded generous sum money country
# 	 states balance order avoid dominated stronger powers ref
#
# Cluster 120, #10 Elements
# 	 city always sporty pau many important facilities several high level sport clubs
# 	 the school provides regular programme school trips enhance curriculum
# 	 in addition high levels fitness attained rowing intense calorie burning exercise
#
# Cluster 121, #10 Elements
# 	 alec green assistant secretary department national savings
# 	 alan wallace coates principal board inland revenue
# 	 charles kirkpatrick county secretary fermanagh ulster savings committee
#
# Cluster 122, #10 Elements
# 	 since early internet traffic increased steadily
# 	 unlimited this expansion actually release base introductory set
# 	 lowering overall cost test equipment labor test operations
#
# Cluster 123, #10 Elements
# 	 private households canton average persons per household ref
# 	 average number residents per living room equal cantonal average per room ref
# 	 private households municipality average persons per household ref
#
# Cluster 124, #10 Elements
# 	 victoria eugenie born october balmoral castle scotland
# 	 june the th armada reaches mozambique island
# 	 one night horacio smoking room sees talita crossing moonlit garden apparently heading bed
#
# Cluster 125, #10 Elements
# 	 roy dowell st ives new south wales
# 	 john raymond huelin como western australia
# 	 michael hayden walsh willoughby new south wales
#
# Cluster 126, #10 Elements
# 	 malcolm edmund brooks walkerville south australia
# 	 mirrie irma hill mosman new south wales
# 	 violet madge curran east brighton victoria
#
# Cluster 127, #10 Elements
# 	 frank henry corner wellington
# 	 helen june patricia evison wellington
# 	 harry leonard riley golden bay
#
# Cluster 128, #10 Elements
# 	 howard graham fleming callam auckland
# 	 colin alexander dickie wellington
# 	 peter leonard newberry auckland
#
# Cluster 129, #10 Elements
# 	 alice elizabeth corballis marton
# 	 norah annie humphreys nelson
# 	 robert hugh rodgers motueka
#
# Cluster 130, #10 Elements
# 	 mills ref
# 	 mills ref
# 	 mills ref
#
# Cluster 131, #10 Elements
# 	 basic
# 	 basic
# 	 basic
#
# Cluster 132, #9 Elements
# 	 julie sinatra born julie ann maria lyma february claims sinatra daughter unacknowledged affair showgirl dorothy bunocelli
# 	 a criminal gang exor come earth steal super friends memories super friends may
# 	 the surveillance bush bush seen first episode last episode
#
# Cluster 133, #9 Elements
# 	 the colony new hampshire adopted temporary constitution
# 	 on november bell left dark matter six weeks ref
# 	 on july bell returned new show midnight desert
#
# Cluster 134, #9 Elements
# 	 trans women like gender variant people face vast amount discrimination transphobia
# 	 the stereotype effeminate boy grows live woman long history ref
# 	 there societal discrimination members unrecognized religious groups particularly considered cults sects
#
# Cluster 135, #9 Elements
# 	 with strong ideology open mindedness lorde impact lesbian society also significant
# 	 wright found casting film difficult particular types people wanted work
# 	 nikolai ostrovsky soviet socialist realist writer ref
#
# Cluster 136, #9 Elements
# 	 armaggon mutant shark exclusive teenage mutant ninja turtles adventures comics
# 	 armaggon appears tv series voiced ron perlman ref
# 	 espn espnhd featured traditional coverage regular football game
#
# Cluster 137, #9 Elements
# 	 positive gdp growth rates masked growing structural problems economy
# 	 this system quite separate general rules control principal acts
# 	 the principles aerodynamic lift shared nature man made aircraft
#
# Cluster 138, #9 Elements
# 	 prior monitor predominated us ibm called dual color green white
# 	 english pancakes like wheat flour cr pes served golden syrup lemon juice sugar
# 	 an example anchorage independent growth assay soft agar assay
#
# Cluster 139, #9 Elements
# 	 an unusual boundary exists town irondequoit adjacent city rochester
# 	 the second taw vale railway extension dock company
# 	 the lswr long designs securing territory devon extending westwards salisbury
#
# Cluster 140, #9 Elements
# 	 many contracts contain clause setting disputes relation contract litigated
# 	 provision rent books information contained offences
# 	 i civilian capacity according brazilian law
#
# Cluster 141, #9 Elements
# 	 early evening disguised loki thor meet rymr assembled j tnar
# 	 ian pender chalmers first secretary hm embassy paris
# 	 david rolland spedding first secretary hm embassy abu dhabi
#
# Cluster 142, #9 Elements
# 	 george malcolm peters taita
# 	 the right honourable arthur christopher john baron soames
# 	 wing commander george richard profit
#
# Cluster 143, #9 Elements
# 	 bern bears ngo basketball club since city bern ref
# 	 nolan arenado baseball player colorado rockies puerto rican mother
# 	 devin booker nba player phoenix suns puerto rican mother
#
# Cluster 144, #9 Elements
# 	 paley born urbana ref illinois daughter jean passovoy hiram paley ref
# 	 audrey swales head teacher barden county junior school burnley
# 	 caroline c fillmore wife president millard fillmore born morristown ref
#
# Cluster 145, #9 Elements
# 	 the primary purpose csp keep msp busy ran slightly x speed msp
# 	 image burn occurs crts plasma panels picture displayed long periods
# 	 the memory manager processes scheduler improved
#
# Cluster 146, #9 Elements
# 	 after initial consonant consonant cluster comes syllabic nucleus one vowels listed
# 	 stress khmer falls final syllable word ref
# 	 adjectives verbs verb phrases may made nouns use nominalization particles
#
# Cluster 147, #9 Elements
# 	 peter gill director riverside studios
# 	 colin james davies managing director doncasters blaenavon ltd
# 	 george paterson principal scottish office
#
# Cluster 148, #9 Elements
# 	 john ellerslie sanderson under secretary department transport
# 	 arthur suddaby provost city london polytechnic
# 	 william affleck easson member invergordon community council
#
# Cluster 149, #9 Elements
# 	 charles stuart masters auckland
# 	 albert charles norman harmer auckland
# 	 stuart leslie devlin london england
#
# Cluster 150, #9 Elements
# 	 by reign eriba adad i bc mitanni influence assyria wane
# 	 he succeeded asharid apal ekur bc reigned two years
# 	 assyria seems recovered dramatically flourished period
#
# Cluster 151, #9 Elements
# 	 ian nelson menzies new plymouth
# 	 the reverend thomas tipper scarlett new farm
# 	 norman merle stadium dedicated march
#
# Cluster 152, #9 Elements
# 	 colonel william alexander dalziel
# 	 commander william nicholas lavington woodley
# 	 captain robert greenhowe the gordon highlanders
#
# Cluster 153, #9 Elements
# 	 moe alma mary dudfield wellington
# 	 william ewart tucker st helens tasmania
# 	 dr edward hammond williams
#
# Cluster 154, #9 Elements
# 	 audre lorde battled cancer fourteen years
# 	 sinatra romantically involved angie dickinson ten years around
# 	 montana married three times
#
# Cluster 155, #9 Elements
# 	 when bern converted protestant reformation unteraargau also converted
# 	 evangelical reformed church kazakhstan
# 	 in france reformed protestants called huguenots
#
# Cluster 156, #9 Elements
# 	 presbyterian church mongolia fruit various korean presbyterian denominations
# 	 evangelical church liechtenstein
# 	 protestant church algeria
#
# Cluster 157, #9 Elements
# 	 ellul identified christian anarchist
# 	 presbyterian church korea koshin kosin
# 	 united church nuwara eliya
#
# Cluster 158, #9 Elements
# 	 s t m i g x
# 	 s t m i g x
# 	 c x c x alpha k x
#
# Cluster 159, #8 Elements
# 	 statements contract may upheld court finds statements subjective promotional puffery
# 	 there definition term bail code though terms bailable non bailable defined ref
# 	 the court gave decision may
#
# Cluster 160, #8 Elements
# 	 shopping carts usually fitted four wheels however one wheel jams cart become difficult handle
# 	 the largest configured s could support mb ram mb disk space
# 	 driver packages used install driver software copied entirety driver store repository driver packages
#
# Cluster 161, #8 Elements
# 	 within year andr e death rexroth married nurse poet marie kass
# 	 after living san francisco years rexroth moved santa barbara
# 	 bonnie lee bakley murdered wife robert blake born morristown ref
#
# Cluster 162, #8 Elements
# 	 the turn millennium brought change school buildings facilities
# 	 the mt vernon car manufacturing company opened moving litchfield illinois
# 	 during year housing buildings made transportation infrastructure made
#
# Cluster 163, #8 Elements
# 	 duarte pacheco replacement capit mor fort manuel cochin nobleman manuel telles de vasconcelos manuel telles barreto according barros
# 	 after recording first ep i here i gone moxie records mendoza left group
# 	 josephus account places date death james ad ref
#
# Cluster 164, #8 Elements
# 	 the top two teams group would qualify quarter finals
# 	 in addition ten time gold glove winner ichiro ten time all star selection
# 	 a player may pass determining game offers opportunities profitable play
#
# Cluster 165, #8 Elements
# 	 the rent act introduced three major innovations
# 	 with critical endorsement borland continued work new material throughout year
# 	 in federal election popular party svp received vote
#
# Cluster 166, #8 Elements
# 	 filling material needs city extracted usually riverbank taguibo river
# 	 the rivers cantabria short rapid descending steeply sea close source cantabrian mountains
# 	 mole previously b gr stroud named local river mole
#
# Cluster 167, #8 Elements
# 	 mantrayana sanskrit may rendered way mantra original self identifying name come determined nyingmapa
# 	 according ihf issue regarding full recognition slovenes remained problematic
# 	 furthermore strang denied god could things insisted things impossible him us ref
#
# Cluster 168, #8 Elements
# 	 robert swanton ballydehob united irishman lawyer new york
# 	 in white appointed one commissioners world fair ref
# 	 simon affolter town chancellor chancelier municipal since municipality
#
# Cluster 169, #8 Elements
# 	 if based illegal purpose contrary public policy contract void
# 	 unpowered flights longer duration distance possible rising air used gain energy
# 	 fire extinguishers sometimes target vandalism schools open spaces
#
# Cluster 170, #8 Elements
# 	 pusk emigrated spain play real madrid
# 	 magadha centre empire also birthplace buddhism
# 	 ambassadors seleucid empire deimachus egypt visited courts
#
# Cluster 171, #8 Elements
# 	 lorde focused discussion difference differences groups women conflicting differences within individual
# 	 compounds however preserve stress patterns constituent words
# 	 the related less common choral score contains choral parts accompaniment
#
# Cluster 172, #8 Elements
# 	 negation achieved putting verb particle end sentence clause
# 	 unilateral mistake occurs one party contract mistaken terms subject matter
# 	 judgement final reasoned decision court guilt innocence accused
#
# Cluster 173, #8 Elements
# 	 solo played wps matches athletica beat league leader saves
# 	 montana became starting quarterback midway season ref
# 	 in montana touchdown passes career high games
#
# Cluster 174, #8 Elements
# 	 printer name paycheck forms buxx device p align yes
# 	 it unfroze contractual rent limit previously fixed registration fair rent could set
# 	 the fax service model fully account based
#
# Cluster 175, #8 Elements
# 	 peter charles alexander chatswood new south wales
# 	 sybil victoria franklin darwin northern territory
# 	 lillian florence monk bexley new south wales
#
# Cluster 176, #8 Elements
# 	 at census median income household town median income family
# 	 of samoa total population census female comprising population
# 	 households consist one person households five people ref
#
# Cluster 177, #8 Elements
# 	 as many human tumors caused viruses ref
# 	 the prognosis individuals pompe disease varies according onset severity symptoms
# 	 the earliest symptoms typically cough shortness breath ref
#
# Cluster 178, #8 Elements
# 	 saibal chatterjee ndtv gave movie stars concluding it may faint hearted prissy
# 	 count dracula appears episode entitled attack vampire
# 	 brainiac also appeared super friends short episode superclones
#
# Cluster 179, #8 Elements
# 	 venus one five turtles exposed mutagen sewers
# 	 leonardo cool calm courageous leader ninja turtles
# 	 michelangelo comedian party dude ninja turtles
#
# Cluster 180, #8 Elements
# 	 she th dame royal order queen maria luisa
# 	 mark evelyn heath hm minister holy see
# 	 owen glyn griffith british high commissioner maseru
#
# Cluster 181, #8 Elements
# 	 phillip ernest o malley chief fire officer waimate volunteer fire brigade
# 	 wilfred jasper burnett secretary unit trust association
# 	 charles hugh branston faulkner director help aged
#
# Cluster 182, #8 Elements
# 	 crohn disease map causes similar disease johne disease cattle
# 	 the joint capsule attaches entire periphery meniscus adheres firmly medial meniscus
# 	 these menisci act distribute body weight across knee joint
#
# Cluster 183, #8 Elements
# 	 morristown green park center town old town common green
# 	 the town pau located minutes pyrenees ski resorts
# 	 seabreeze a hamlet northern part irondequoit along irondequoit bay
#
# Cluster 184, #8 Elements
# 	 the university inaugurated president jacques chirac president hosni mubarak ref
# 	 meli vakarewakobau assistant commissioner royal fiji police force
# 	 ronald ernest groves member cherwell district council
#
# Cluster 185, #8 Elements
# 	 total students attending school municipality
# 	 many students attend instrumental classes school day
# 	 in school pupils enrolled grades kindergarten third grade
#
# Cluster 186, #8 Elements
# 	 flight sergeant roger wilfred louis f
# 	 flight sergeant gordon phillip nicholls a
# 	 flight lieutenant john jeffrey wilkinson
#
# Cluster 187, #8 Elements
# 	 genres emerged explore homosexual romances
# 	 bell interests however extend beyond paranormal
# 	 the circumstances cabot death appear obscure contradictory
#
# Cluster 188, #8 Elements
# 	 his vice president itamar franco assumed presidency remainder collor term
# 	 edelmiro a amante sr former executive secretary pres
# 	 as said earlier act disapplied act board attendance furniture provided
#
# Cluster 189, #8 Elements
# 	 the church replaced church sacred heart built
# 	 protestant reformed christian church croatia
# 	 reformed church transcarpathia transcarpathian hungarians followers reformed faith
#
# Cluster 190, #8 Elements
# 	 the tuna sleek streamlined fish adapted speed
# 	 castor oil oil made seeds castor oil plant
# 	 walnuts large hard edible seeds tree genus juglans
#
# Cluster 191, #8 Elements
# 	 phil judy reveal bob engagement phony
# 	 thomas william darcy hughes albany
# 	 roger thomas baldwin fulford political public service
#
# Cluster 192, #8 Elements
# 	 valerie elizabeth cook headmistress la retraite high school bristol
# 	 raymond maurice whitfield senior principal home office
# 	 charlotte mclaren dowdles head instructor newhills school glasgow
#
# Cluster 193, #8 Elements
# 	 howard byron danby thames
# 	 john holdsworth nairn waipawa
# 	 david mandie toorak
#
# Cluster 194, #8 Elements
# 	 pau features wet mild winters warm mild summers drier
# 	 and earth one changed luminosity sun increased time
# 	 lausanne average days rain snow per year average receives precipitation
#
# Cluster 195, #8 Elements
# 	 according bajpayee role sardar khan negative role done till date
# 	 the vesnins continued competing contracts ukraine specifically kharkiv
# 	 the issue finally settled study saward
#
# Cluster 196, #8 Elements
# 	 make u believer produced frank dukes
# 	 like hott boyy featuring young thug bricc baby shitro produced dj spinz
# 	 still selling dope featuring fetty wap
#
# Cluster 197, #8 Elements
# 	 terri gibbs country music singer musician
# 	 geoffrey gurrumul yunupingu indigenous australian singer songwriter
# 	 blind willie mctell blues guitarist ref
#
# Cluster 198, #8 Elements
# 	 people single never married municipality
# 	 people single never married municipality
# 	 people single never married municipality
#
# Cluster 199, #8 Elements
# 	 victor edwin jaynes wellington
# 	 dorothy brenda isabel ruth brown invercargill
# 	 paris chambers hughesdale victoria
#
# Cluster 200, #8 Elements
# 	 s gabriel da cachoeira nheengatu tukano baniwa ref ref
# 	 tun datuk patinggi abang muhammad salahuddin abang barieng rd th governor sarawak ref
# 	 tun datuk patinggi ahmad zaidi adruce th governor sarawak ref
#
# Cluster 201, #8 Elements
# 	 aargau population
# 	 lausanne population
# 	 population male female
#
# Cluster 202, #8 Elements
# 	 aargau unemployment rate
# 	 uttigen unemployment rate
# 	 lausanne unemployment rate
#
# Cluster 203, #8 Elements
# 	 itueta district vila nietzel ref ref ref
# 	 espig oeste approval ref ref ref ref
# 	 venda nova imigrante ref ref
#
# Cluster 204, #8 Elements
# 	 in commune inhabitants
# 	 uttigen population
# 	 population aden colony
#
# Cluster 205, #7 Elements
# 	 the following table shows conventionally accepted historical stages khmer ref
# 	 over time puranas epics composed concepts worship virtues spirituality evolved hinduism
# 	 assyrian art preserved present day predominantly dates neo assyrian period
#
# Cluster 206, #7 Elements
# 	 a gang heavily armed men scour finally narrow house wasseypur
# 	 some ealing businesses asked police close pm ref
# 	 scotland yard stated people arrested charged ref
#
# Cluster 207, #7 Elements
# 	 there debates whether civil disobedience must necessarily non violent
# 	 the discourses other early political writings trans
# 	 in bju reemerged campaign stop significance conservative republicans
#
# Cluster 208, #7 Elements
# 	 during fifth season three episodes bring notable personalities
# 	 the early successful period parramatta earned five grand final appearances four premierships
# 	 the presidential term set four years set six years since
#
# Cluster 209, #7 Elements
# 	 alderman noel frank bullpitt bundaberg queensland
# 	 captain jeremy john mainwaring burton irish guards
# 	 tom sullivan american musician author motivational speaker
#
# Cluster 210, #7 Elements
# 	 other businesses mollie included general store cider mill blacksmith shop
# 	 stanley ernest wood higgs director office machines equipment federation
# 	 ferguson kennedy sector building officer lennox castle hospital
#
# Cluster 211, #7 Elements
# 	 anti intellectualism continued remain relevant st century
# 	 the late gothic church built promptly burned
# 	 in transylvania reformed faith took root th century
#
# Cluster 212, #7 Elements
# 	 geoffrey woodhead head technology division northern spinning division courtaulds ltd
# 	 marine engineering artificer h david cook m c
# 	 the technopoles h lioparc pau cit multim dia pole e business southern aquitaine peba
#
# Cluster 213, #7 Elements
# 	 one ma satisfactory mayoral construction maokong gondola
# 	 construction completed hydrogen fueling station campus
# 	 effective may delta air lines moving terminals vacating terminals ref
#
# Cluster 214, #7 Elements
# 	 lesser numbers gists appear associated neither c kit pdgfr abnormalities ref
# 	 the s could compile run programs kb size although large
# 	 new protected shorthold tenancies created protected contractual term short fixed term letting
#
# Cluster 215, #7 Elements
# 	 ross phillip dallow inspector new zealand police
# 	 maurice anthony bracken lately superintendent metropolitan police
# 	 leonard arthur gillert commander metropolitan police
#
# Cluster 216, #7 Elements
# 	 john rowland dart st ives new south wales
# 	 sarah myrtle marshall albert park south australia
# 	 samuel cocking bus driver bristol omnibus co ltd
#
# Cluster 217, #7 Elements
# 	 reported harassment police reporting physical assaulted reporting sexual assault officer
# 	 lois mary parkin wages officer hants dorset motor services ltd
# 	 mario payas detective inspector police gibraltar police force
#
# Cluster 218, #7 Elements
# 	 thomas alexander mcgowran managing director f johnston co ltd
# 	 robert lancelot paterson director merseyside chamber commerce industry
# 	 frederick harold tapping works manager rolls royce ltd
#
# Cluster 219, #7 Elements
# 	 mildred clary services british cultural interests france
# 	 commander order isabella catholic spain ref
# 	 the flag brittany inspired part american flag
#
# Cluster 220, #7 Elements
# 	 savings taxes imports investment government spending exports
# 	 an income tax neither poll tax capitation amount tax vary person person depending person income
# 	 the grameen bank grown two dozen enterprises grameen family enterprises
#
# Cluster 221, #7 Elements
# 	 wagon new york hawaii
# 	 john sinclair leslie hill moree new south wales
# 	 elizabeth mary mcdonald leura new south wales
#
# Cluster 222, #7 Elements
# 	 much unionist leadership assassinated operation nemesis
# 	 kitchener continued lose favour politicians professional soldiers
# 	 turkey admitted league nations ref
#
# Cluster 223, #7 Elements
# ...
# 	 gangs wasseypur collected cr first four days
# 	 the school around day pupils small proportion total
# 	 education provided children boys girls least intermediate level
#
# Cluster 486, #5 Elements
# 	 catherine bourbon sister henri iv governed b arn place
# 	 when rousseau reached de warens took lover intimate also steward house
# 	 jim married joy later divorced
#
# Cluster 487, #5 Elements
# 	 adult males less ready pursue less efficient catching adult females especially larger prey
# 	 there residents obergesteln employed capacity females made workforce
# 	 there residents oberwald employed capacity females made workforce
#
# Cluster 488, #5 Elements
# 	 dr neil degrasse tyson astrophysicist television radio hostdr
# 	 in ren barth lemy developed line television standard
# 	 digital television transition started late
#
# Cluster 489, #5 Elements
# 	 renovated bosquet centre shopping centre contemporary architecture centre town
# 	 shippensburg area middle school located park place shippensburg
# 	 in grand terrace chamber commerce organized
#
# Cluster 490, #5 Elements
# 	 by borland lived severe depression years ref
# 	 infantile onset form usually diagnosed months
# 	 ted diagnosed terminal disease ref
#
# Cluster 491, #5 Elements
# 	 during typical fall season events take place turf
# 	 after regaining promotion second division boro good form
# 	 the results championship included surprises
#
# Cluster 492, #5 Elements
# 	 onslow village sloped suburb western outskirts guildford
# 	 the municipality located plateau de diesse foot chasseral peak
# 	 the main road associated morgul pass way mountains shadow mordor
#
# Cluster 493, #5 Elements
# 	 captain robin john pashley heath
# 	 wing commander keith owen harding
# 	 wing commander terence john nash
#
# Cluster 494, #5 Elements
# 	 jewish soldiers assisted childeric war wamba
# 	 crimean tatar media particularly targeted russian repression
# 	 like many germans time goebbels antisemitic young age
#
# Cluster 495, #5 Elements
# 	 an eye empty point group points surrounded one player stones
# 	 a third technique capture stones snapback ref
# 	 the middle phase game combative usually lasts moves
#
# Cluster 496, #5 Elements
# 	 similarly anglican church saint andrew built
# 	 st josaphat ukrainian catholic church
# 	 bible presbyterian church singapore
#
# Cluster 497, #5 Elements
# 	 sarah price born author ref
# 	 count jennifer lynn furminger last seen
# 	 count heather chinnook last seen april
#
# Cluster 498, #5 Elements
# 	 jerec star wars character served emperor palpatine inquisitor
# 	 liezel huber bob bryan defeated vania king marcelo melo
# 	 meanwhile wilmot separated king gone wrong bridport inn
#
# Cluster 499, #5 Elements
# 	 maisie gallagher cleaner department for national savings
# 	 cargo operations port djibouti chief economic activity djibouti
# 	 the canadian unit created purchase aikenhead hardware
#
# Cluster 500, #5 Elements
# 	 robert stewart lockwood palmerston north
# 	 thomas michael noel rodgers palmerston north
# 	 chief superintendent john daltoft revill
#
# Cluster 501, #5 Elements
# 	 just like tool afm usefulness limitations
# 	 the fundamental principle sardar thought one way human
# 	 if person fails improve trying treatments arthroscopy considered
#
# Cluster 502, #5 Elements
# 	 clifford willetts member dudley metropolitan borough council
# 	 chitr founded october parochial district distrito parroquial
# 	 on february town sibu burnt ground
#
# Cluster 503, #5 Elements
# 	 cobol fortran rpg generated object code type o
# 	 dfu programs generated subroutine r code wsu programs
# 	 screen formats generated object code
#
# Cluster 504, #5 Elements
# 	 mollie post office established october
# 	 coso blanco first friday july castro urdiales
# 	 in november haringey offering hall sale
#
# Cluster 505, #5 Elements
# 	 before release lp reached test pressing stage pross fired elektra
# 	 the lswr continued doubling towards lidford completing december
# 	 after season marlins exercised option ichiro contract season added option season ref
#
# Cluster 506, #5 Elements
# 	 hirsch horeb especially important source exposition philosophy mitzvot
# 	 the distinction dharani mantra difficult make
# 	 there numerous important mantras ref
#
# Cluster 507, #5 Elements
# 	 ames municipal airport located southeast city
# 	 high ground located north mt
# 	 additionally number restaurants located throughout city
#
# Cluster 508, #5 Elements
# 	 bindusara died bce records say bce succeeded son ashoka
# 	 thompson catholic opposes abortion
# 	 the gemara told phinehas killed zimri cozbi israelites began berating phinehas presumption descended midianite idolater jethro
#
# Cluster 509, #5 Elements
# 	 the finalists assigned four groups group four teams
# 	 a three time olympian earned gold medals ref
# 	 after season solo named wps goalkeeper year
#
# Cluster 510, #5 Elements
# 	 it fallacy opinion cannot statement fact
# 	 man exalted paradoxical though may seem means crushing man
# 	 det vil aldrig ske that never happen prediction det skal ej ske that shall happen promise
#
# Cluster 511, #5 Elements
# 	 the city endowed swamplands near coastal area
# 	 dominica partially integrated federal colony leeward islands
# 	 it soon clear land part group islands
#
# Cluster 512, #5 Elements
# 	 in fisher married young woman engaged another
# 	 the nansen family originated denmark
# 	 valentino born rodolfo pietro filiberto raffaello guglielmi ref castellaneta apulia kingdom italy
#
# Cluster 513, #5 Elements
# 	 kathleen sutton member thamesdown citizens advice bureau wiltshire
# 	 sheila holtom telephone operator coventry skillcentre department employment
# 	 bramduth ghoorah secretary cabinet head civil service
#
# Cluster 514, #5 Elements
# 	 some feminists argue medicalization asexuality ref
# 	 nevertheless lesbian feminists julie bindel still critical bisexuality
# 	 some lesbian feminists julie bindel still critical bisexuality
#
# Cluster 515, #5 Elements
# 	 performance address translation buffers enhanced
# 	 the d capabilities wpf limited compared available direct d
# 	 for higher frequencies inductors made cores ferrite
#
# Cluster 516, #5 Elements
# 	 john graeme sinclair reid auckland
# 	 peter john derham toorak victoria
# 	 patrick john vance ramsden armadale victoria
#
# Cluster 517, #5 Elements
# 	 premises came protection tenants died moved away
# 	 phillip enright main character the cay becomes temporarily blind due concussion
# 	 nansen died heart attack home may
#
# Cluster 518, #5 Elements
# 	 maureen frances fraser gamble secretary association nurse administrators
# 	 percy tayler principal department health social security
# 	 frank whipp lately principal department trade
#
# Cluster 519, #5 Elements
# 	 total number full time equivalent jobs
# 	 quasars luminosities variable time scales range months hours
# 	 total number full time equivalent jobs
#
# Cluster 520, #5 Elements
# 	 norman george goffin lower hutt
# 	 martyn rudolph finger darwin northern territory
# 	 percival vincent dunning bicton western australia
#
# Cluster 521, #5 Elements
# 	 the havanese dark brown eyes almond shaped lids surrounded black pigment
# 	 the stem green lanceolate scarious membranous spathes leaves flower bud
# 	 the flowers iris kemaonensis used tibetan herbal medicine
#
# Cluster 522, #5 Elements
# 	 adolf frankel chairman staveley industries ltd
# 	 eric jameson chairman e jameson associates
# 	 ruhita ashoka chand chairman wolverhampton centre national trust
#
# Cluster 523, #5 Elements
# 	 marx distinguishes simple reproduction expanded enlarged reproduction ref
# 	 the first life arose abiotic chemical reactions
# 	 paleomagnetics study planet ancient magnetic field
#
# Cluster 524, #5 Elements
# 	 jan wicker cloverdale western australia
# 	 the farmland canton aargau fertile switzerland
# 	 strychnos nux vomica tree native asia bark contains strychnine
#
# Cluster 525, #5 Elements
# 	 ronald william greenough te awamutu
# 	 william david skelton levin
# 	 clifford clarence gabelle foreign commonwealth office
#
# Cluster 526, #5 Elements
# 	 iv commend professional scientific artistic
# 	 biogeography study geographic distribution life time
# 	 religion major aspect life curriculum bju
#
# Cluster 527, #5 Elements
# 	 warrant officer donald dykes m
# 	 warrant officer trevor charles hardcastle b
# 	 warrant officer donald pagel q
#
# Cluster 528, #5 Elements
# 	 the name town recorded th century
# 	 patan established chapotkata ruler vanaraja th century anahilapataka ref
# 	 the church aarberg western border bishopric constance built
#
# Cluster 529, #5 Elements
# 	 jim safe bomb dream ref
# 	 on april oberfeldwebel fritz timm jg shot lancaster
# 	 on december jg lost unteroffizier gerhard hartwig rudolf wezulek mesum oberfeldwebel werner essinger bailing burgsteinfurt
#
# Cluster 530, #5 Elements
# 	 when sweet eaten part breakfast dessert
# 	 tented merchants sold whiskey porter bread
# 	 salvivad place patolas woven along places traditional clay toys made worth visiting
#
# Cluster 531, #5 Elements
# 	 the band continued play live looking another record deal
# 	 the season began three signings
# 	 on may ichiro recorded th professional hit
#
# Cluster 532, #5 Elements
# 	 charlotteville area south east town
# 	 bukit aup jubilee park opened march
# 	 memorial park city cemetery columbarium
#
# Cluster 533, #5 Elements
# 	 samuel mcveigh senior foreman steelworker harland wolff
# 	 n c jamieson chief officer
# 	 graham carpenter zoe archie carpenter father
#
# Cluster 534, #5 Elements
# 	 of population age college degree
# 	 population age years age older
# 	 the age distribution age years age older
#
# Cluster 535, #5 Elements
# 	 in school admitted first girl joined lower sixth
# 	 an application register female school made
# 	 by school enrolment reached boys
#
# Cluster 536, #5 Elements
# 	 bertram alfred young dramatic critic financial times
# 	 karen received positive reactions critics
# 	 by time club begun attract mainstream attention
#
# Cluster 537, #5 Elements
# 	 injection means introduction income flow
# 	 the deposit varies usually coins higher value used
# 	 notice total higher multiple answers
#
# Cluster 538, #5 Elements
# 	 some plants also use wind seed dispersal way
# 	 assyria needed less artificial irrigation babylonia horse breeding extensive
# 	 water resistance models consist paddle revolving enclosed tank water
#
# Cluster 539, #5 Elements
# 	 the most noble ann fortune duchess grafton
# 	 jardine bachelor willed estate siblings nephews
# 	 the baker family source many stories
#
# Cluster 540, #5 Elements
# 	 there lakes mi streams rivers
# 	 the electrical conductivity eddy creek measured
# 	 the streambed eddy creek dry reaches
#
# Cluster 541, #5 Elements
# 	 a miniature score like full score much reduced size
# 	 dominica relatively large number centenarians
# 	 buildings typically circular diameters meters walls cm thick
#
# Cluster 542, #5 Elements
# 	 however stanowski crash land due lack fuel
# 	 we find argument fraught difficulties
# 	 in wake mcmahon unusual duality persisted
#
# Cluster 543, #5 Elements
# 	 ma took office may ref
# 	 in december elections dlp seats
# 	 matsko called robbins office november
#
# Cluster 544, #5 Elements
# 	 persistent significant swelling stiffness knee
# 	 allergic reactions unlikely occur
# 	 alprazolam metabolites excreted primarily urine
#
# Cluster 545, #5 Elements
# 	 when town founded road
# 	 the epicentre located km west christchurch
# 	 obergesteln followed oberwald right north bank rhone unterwassern opposite bank rhone
#
# Cluster 546, #5 Elements
# 	 richard malcolm leach waihi
# 	 john renata blackman te kuiti
# 	 ratu henry barkeley vakaruru qasevakatini
#
# Cluster 547, #5 Elements
# 	 chief yeoman warder leslie varley
# 	 warrant officer roy millington u
# 	 abbot vincent dorin played adrian schiller
#
# Cluster 548, #5 Elements
# 	 in situation phase current lags voltage
# 	 l inductance i current inductor
# 	 the neutron gyromagnetic ratio symbol n ref
#
# Cluster 549, #5 Elements
# 	 the town two railway stations
# 	 starting people began use automobiles rather train
# 	 taxis sibu operates hours day ref
#
# Cluster 550, #5 Elements
# 	 a khmer syllable begins single consonant else cluster two rarely three consonants
# 	 adjectives demonstratives numerals follow noun modify
# 	 adjectival verbs word class equivalent english
#
# Cluster 551, #5 Elements
# 	 taufik suliman cotran chief justice lesotho
# 	 bernard edwin hotson chief superintendent cambridgeshire constabulary
# 	 w b innes chief engineer
#
# Cluster 552, #5 Elements
# 	 peggy pelchen gladstone victoria
# 	 lena regan point lonsdale victoria
# 	 henrietta gladys jones coorparoo
#
# Cluster 553, #5 Elements
# 	 in syllable final position approach respectively
# 	 there two first editions neither dates
# 	 nansen first task return write account voyage
#
# Cluster 554, #5 Elements
# 	 the moeller crusaders long history athletic success
# 	 in nansen passed university entrance examination examen artium
# 	 djibouti city long center media country
#
# Cluster 555, #5 Elements
# 	 conf rence sur l apocalypse de jean
# 	 madame de cavoye louis eustache dauger de cavoye mother
# 	 le si cle de louis xiv the age louis xiv
#
# Cluster 556, #5 Elements
# 	 his father manohar krishna mulay farmer tailor mother akkatai mulay homemaker
# 	 bindusara son first mauryan emperor chandragupta maurya queen durdhara
# 	 bindusara life documented well father chandragupta son ashoka
#
# Cluster 557, #5 Elements
# 	 pau located west toulouse tarbes lourdes oloron
# 	 patan railway station km ahmedabad railway station
# 	 the nearest airport sardar vallabhbhai patel international airport ahmedabad
#
# Cluster 558, #5 Elements
# 	 the length foot elbow equal length elbow withers
# 	 knees bent shins vertical position
# 	 exercises strengthen muscles around knee especially quadriceps
#
# Cluster 559, #5 Elements
# 	 peter dinklage born actor ref
# 	 fran lebowitz born author ref
# 	 in gaston iv foix b arn married infanta eleanor aragon transferred court orthez pau ref
#
# Cluster 560, #5 Elements
# 	 p fimbriata one species genus portia may ref
# 	 the species p fimbriata originally described carl ludwig doleschall salticus fimbriata ref
# 	 it common name kumaon iris ref ref kumon iris ref
#
# Cluster 561, #5 Elements
# 	 a coeduational day school kept samuel hatfield
# 	 in shippensburg area students took sat exams
# 	 in noguchi entered mitsuwa elementary school
#
# Cluster 562, #5 Elements
# 	 the famed novelist jean rhys born raised dominica
# 	 constantine appeared film constantine portrayed keanu reeves
# 	 james mangold screenwriter director ref
#
# Cluster 563, #5 Elements
# 	 in th century john philoponus c
# 	 the historian alwyn ruddock worked cabot era years
# 	 andres ramos mattei historian ref
#
# Cluster 564, #5 Elements
# 	 wessely completed medical rotation newcastle
# 	 mona griffin general medical practitioner aberdeen
# 	 nora kathleen woll general medical practitioner bottesford nottingham
#
# Cluster 565, #5 Elements
# 	 economic growth uneven
# 	 however stalin continued demand even far reaching sacrifices
# 	 education poor one lansbury major concerns
#
# Cluster 566, #5 Elements
# 	 b dziemy wili mp wi nmp wi we say saying
# 	 rwy n mynd weld ffilm yfory i going see film tomorrow
# 	 the going future e g john going leave tonight
#
# Cluster 567, #5 Elements
# 	 sargon i arru k n i c
# 	 pi a le l
# 	 l mathrm eq l l cdots l n
#
# Cluster 568, #5 Elements
# 	 he voiced jamieson price
# 	 he voiced ezra weisz
# 	 she voiced karen strassman judgment
#
# Cluster 569, #5 Elements
# 	 ziauddin sardar born dipalpur pakistan
# 	 noguchi hideyo born inawashiro fukushima prefecture
# 	 edith jeanette soterius von sachsenheim born december marienburg feldioara
#
# Cluster 570, #5 Elements
# 	 there financial sector
# 	 there government sector
# 	 there foreign sector
#
# Cluster 571, #5 Elements
# 	 apartments municipality
# 	 the town besieged taken
# 	 the village church built
#
# Cluster 572, #5 Elements
# 	 elizabeth may pearson berwick
# 	 estelle may waterman bendigo
# 	 hvidbj rnen reached copenhagen may
#
# Cluster 573, #5 Elements
# 	 bern portion aargau came known unteraargau though also called berner bernese aargau
# 	 uttigen first mentioned utingun ref
# 	 irilin d c h o also found rhizomes ref
#
# Cluster 574, #5 Elements
# 	 the aleppo codex lacks lamentations entirety
# 	 the aleppo codex lacks ecclesiastes entirety
# 	 the aleppo codex lacks daniel entirety

# %%
cluster_list = []
for i, cluster in enumerate(clusters):
  cluster_list.append(cluster)

# %%
sen = []
for i, cluster in enumerate(clusters):
  for id in cluster[:]:
    sen.append([i, training_data[id]])

# %%
df=pd.DataFrame(sen,columns=['cluster_no','sentences'])
df.head(20)
# Out:
#     cluster_no                                          sentences
# 0            0  moeller student run newspaper the crusader con...
# 1            0  in the crusader first place second highest hon...
# 2            0  the squire student literary journal features s...
# 3            0  archbishop moeller high school established fal...
# 4            0  when opened doors moeller high school received...
# 5            0  quite number countermeasures installed counter...
# 6            0  the moeller art program nationally recognized ...
# 7            0  the lacrosse team two state titles constant fo...
# 8            0  moeller high school athletic teams exception b...
# 9            0  recently moeller unveiled plans build multipur...
# 10           0  the title went second team ohio high school bo...
# 11           0  the abstraction ignores linear throughput matt...
# 12           0  this say circular flow diagram useful understa...
# 13           0  the circular flow income concept better unders...
# 14           0  alternatively one think transactions terms mon...
# 15           0  the circular flow diagram illustrates interdep...
# 16           0  one earliest ideas circular flow explained wor...
# 17           0  fran ois quesnay developed concepts first visu...
# 18           0  first regulation impedes flow income throughou...
# 19           0  second taxes productive classes farmers reduce...

# %% [markdown]
# ### Saving csv file of cluster

# %%
df.to_csv('infersent_clustering.csv')

# %% [markdown]
# ### Sentence Embeddings using Siamese BERT-Networks

# %%
import tensorflow_hub as hub
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
# !pip install sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
#sentence_embeddings = model.encode(training_data)

# %%
#with open('sentence_embeddings_bert.pickle', 'wb') as handle:
#    pickle.dump(sentence_embeddings, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('/content/gdrive/MyDrive/sentence_embeddings_bert.pickle', 'rb') as handle:
    sentence_embeddings = pickle.load(handle)

# %%
print('Sample BERT embedding vector - length', len(sentence_embeddings[0]))
# Out:
# Sample BERT embedding vector - length 768

# %%
clusters1 = cluster_detection(sentence_embeddings, min_community_size=5, threshold=0.65)

# %% [markdown]
# ### Results of clustering

# %%
for i, cluster in enumerate(clusters1):
    print("\nCluster {}, #{} Elements ".format(i+1, len(cluster)))
    for sentence_id in cluster[0:3]:
        print("\t", training_data[sentence_id])
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Cluster 253, #14 Elements
# 	 afm probes manufactured mems technology
# 	 system environment mode feature as used run ocl rpg ii programs os
# 	 disk space system organized blocks
#
# Cluster 254, #14 Elements
# 	 chapters collected heading from side action takes place argentina
# 	 horacio returns buenos aires stopping la maga hometown montevideo way
# 	 south american explorers founded journalist donald james montague south american explorers club
#
# Cluster 255, #14 Elements
# 	 a complete khmer sentence consists four basic elements include optional topic optional subject obligatory predicate various adverbials particles ref
# 	 passing four digit code assembler routine returned associated text
# 	 there four different ways contracts set aside
#
# Cluster 256, #13 Elements
# 	 her second volume cables rage mainly written tenure poet residence tougaloo college mississippi addressed themes love betrayal childbirth complexities raising children
# 	 jonaki collection poetry marathi passionate poems young sensitive mind trying figure hidden meanings social political cultural economic happenings times
# 	 rexroth central figure san francisco bay area poetry exercised major early influence evolution area local artistic culture social counterculture
#
# Cluster 257, #13 Elements
# 	 walter wilhelm schauble ferny creek victoria
# 	 john russell anderson professor pathology university glasgow
# 	 frederick william rimmer gardiner professor music university glasgow
#
# Cluster 258, #13 Elements
# 	 mary whitehouse general secretary national viewers listeners association
# 	 winifred lilian jordan organiser secretary east belfast community council
# 	 caroline c fillmore wife president millard fillmore born morristown ref
#
# Cluster 259, #13 Elements
# 	 john knox divisional commander fire authority for northern ireland
# 	 alan burns sub officer northumberland fire brigade
# 	 james mcginley electrician thoresby colliery north notts area national coal board
#
# Cluster 260, #13 Elements
# 	 the increase bolivian immigrants brazil one social consequences political crisis affecting country ref
# 	 in essay elaborates ideas introduced discourse arts sciences rousseau traces man social evolution primitive state nature modern society
# 	 rousseau claimed state nature primitive condition without law morality human beings left benefits necessity cooperation
#
# Cluster 261, #13 Elements
# 	 in jesuit capuchin missionaries began proselytize among syriac orthodox faithful aleppo forming larger pro catholic movement within syriac orthodox church
# 	 rousseau break encyclopedistes coincided composition three major works emphasized fervent belief spiritual origin man soul universe contradistinction materialism diderot la mettrie d holbach
# 	 ellul identified christian anarchist
#
# Cluster 262, #13 Elements
# 	 as march murder charge involving unidentified victim lifted
# 	 bugs an aging farmer repeatedly told account shooting burying two bigfoot creatures back texas panhandle initially thinking bears
# 	 in october bell interviewed temple vampire representative nemo
#
# Cluster 263, #13 Elements
# 	 her father died active military service contracting fever africa
# 	 halcyon hal green character short story the diary luke castellan percy jackson olympians series blind seer antagonist luke castellan befriended long fall grace
# 	 stanislaus anthony kowalewski youngest five baseball playing brothers coal mining community shamokin pennsylvania ref
#
# Cluster 264, #13 Elements
# 	 in driverless shopping cart made chaotic moon labs ref
# 	 when chronos distorts time gotham city super friends stop
# 	 looters burned sony owned warehouse solar way enfield ref acted primary distribution hub independent music distributor pias entertainment group ref
#
# Cluster 265, #13 Elements
# 	 but besides introducing changes long term affected future rent officer role housing act created important new additional functions relating assessment housing benefit subsidy
# 	 a house flat constructed building licence defence regulations made emergency powers defence acts could subject condition limiting price sale rent permitted rent
# 	 the housing repairs rents act sought encourage landlords repair controlled houses allowing repairs increase rent houses brought
#
# Cluster 266, #13 Elements
# 	 in luiz in cio lula da silva pt workers party presidency national vote
# 	 the oryx gtl plant qatar joint venture sasol qatar petroleum launched
# 	 the university inaugurated president jacques chirac president hosni mubarak ref
#
# Cluster 267, #13 Elements
# 	 cumberland lower blackstone valley rhode island john h chafee blackstone river valley national heritage corridor new england historic national park area
# 	 gene shalit born film critic nbc the today show ref
# 	 the tradition stretched new century teddy frankie arundel frank gerard coughlan tommy arundel tony mc loughlin involved
#
# Cluster 268, #13 Elements
# 	 at common law elements contract offer acceptance intention create legal relations consideration
# 	 the landlord tenant act consolidated certain provisions relating law landlord tenant formerly found housing acts rent acts various places
# 	 fok hin kwong law clerk legal aid department hong kong
#
# Cluster 269, #13 Elements
# 	 intermediate numbers formed compounding elements
# 	 in town population spread age years age older
# 	 in town population spread age years age older
#
# Cluster 270, #13 Elements
# 	 the tom doug show paley regular guest nationally syndicated tom doug radio show weekly comedy music show pacifica radio network ref
# 	 in us uk universal studios home entertainment released standard vhs dvd february widescreen fullframe attached bonus features included audio commentary director joe wright look austen life ending scene elizabeth darcy kissing
# 	 cummings son tony cummings played rick halloway nbc daytime serial another world early
#
# Cluster 271, #13 Elements
# 	 maati pankh aani aakash autobiographical novel marathi ref ref a true story regarding success democratic polity post independent india
# 	 in germanic areas occupied roman empire coins votive objects dating nd rd century ad found latin inscriptions referring hercules reality varying levels likelihood refer thor way interpretatio romana ref
# 	 the concept conatus used baruch spinoza psychology derived sources ancient medieval
#
# Cluster 272, #13 Elements
# 	 from lorde brief affair sculptor painter mildred thompson
# 	 there right succession tenant widow residing death member tenant family residing tenant time death
# 	 nancy agnes mcaleese laundry worker roe valley hospital limavady
#
# Cluster 273, #13 Elements
# 	 with new developments surrounding old unfinished sports complex facility city government transferred sports complex hectare complex brgy
# 	 after living san francisco years rexroth moved santa barbara
# 	 st peter church built prix de rome architect
#
# Cluster 274, #13 Elements
# 	 robert f kennedy jr nationally syndicated american radio program
# 	 the flag brittany inspired part american flag
# 	 asl possesses set signs known american manual alphabet used spell words english language ref
#
# Cluster 275, #13 Elements
# 	 on march bell received lifetime achievement award trade publication radio records los angeles ref
# 	 the birthplace bernadotte museum today particular interest swedish tourists dates th century
# 	 while gardens open throughout year thatched manor open public guided visits summer months ref
#
# Cluster 276, #13 Elements
# 	 in led successful bid national institute health research establish health protection research unit hpru emergency preparedness response chairs ref
# 	 during eu referendum one leaders healthier in campaign making case science health ref
# 	 although regarded house augustinian canons regular arrouaise followed stricter code conduct augustinians modelled explicitly cistercians time gervais ref
#
# Cluster 277, #13 Elements
# 	 in general court established statute unified court system making chief justice supreme court responsible efficient operation courts new hampshire
# 	 contracts widely used commercial law form legal foundation transactions across world
# 	 ma formed silk road ensemble following famous trade route several hundred years ago used trade notably spices way across europe asia china
#
# Cluster 278, #13 Elements
# 	 television director joe wright hired early making pride prejudice directional feature film debut
# 	 th century fox borrowed moon over miami enormously successful betty grable musical
# 	 cummings chosen producer john wayne co star play airline pilot captain sullivan the high mighty partly due cummings flying experience however director william a wellman overruled wayne hired robert stack part ref
#
# Cluster 279, #13 Elements
# 	 the goal unit testing isolate part program show individual parts correct ref
# 	 in case unit tests written first act design document specifying form behaviour desired solution implementation details left programmer
# 	 crucially test code considered first class project artifact maintained quality implementation code duplication removed
#
# Cluster 280, #13 Elements
# 	 in british supermarket chain tesco trialed shopping carts user adjustable wheel resistance heart rate monitoring calorie counting hardware effort raise awareness health issues
# 	 beatles guitarist george harrison bought guitar fenton music store mt
# 	 in decca label took control british crown label uk based rex label also issued early singles lynn including harbour lights
#
# Cluster 281, #13 Elements
# 	 at census median income household town median income family
# 	 the median income household town median income family
# 	 under compulsory private pension system formal sector employees pay salaries privately managed funds ref
#
# Cluster 282, #13 Elements
# 	 stockton located th congressional district ref part new jersey th state legislative district ref
# 	 rowing atlantic first became mainstream first atlantic rowing race launched sir chay blyth reflecting ocean row propelled international renown
# 	 through contacts bennington johanson became part new york art world
#
# Cluster 283, #13 Elements
# 	 sold counter places tobacco stores burlesque houses millions tijuana bibles sold height popularity
# 	 corner gas spawned merchandising business hundreds retail items sold live touring productions best selling dvds
# 	 among career highlights the catch game winning touchdown pass vs dallas nfc championship game super bowl winning yard drive bengals super bowl xxiii staples nfl highlight films
#
# Cluster 284, #13 Elements
# 	 reiki procedure practitioner might look blow tap touch patient attempt affect energy body
# 	 livingston wheeler therapy therapeutic regime included restricted diet various drugs therapy use enemas
# 	 in chemical study carried rhizomes iris kemanonensis found several compounds including benzoquinone ref
#
# Cluster 285, #13 Elements
# 	 one feature s basic fortran exclusive
# 	 consideration concept devised english common law required simple contracts special contracts contracts deed
# 	 most simple formulas area follow method dissection
#
# Cluster 286, #13 Elements
# 	 hany nasr el din invited assist supports finals studies master degree
# 	 montana graduated notre dame degree business administration marketing
# 	 the university michigan conferred honorary master arts degree white ref
#
# Cluster 287, #13 Elements
# 	 tony hunter professional football player buffalo bills los angeles rams
# 	 neil o donnell born former nfl quarterback notably pittsburgh steelers ref
# 	 montana began season san francisco starting quarterback
#
# Cluster 288, #13 Elements
# 	 cardoso administration also placed strong focus external affairs
# 	 the court hears variety cases either mandatory discretionary appeals lower courts
# 	 although sheet music often thought platform new music aid composition e composer writes music also serve visual record music already exists
#
# Cluster 289, #13 Elements
# 	 the season feature the orchestra age enlightenment eighth blackbird pacifica quartet sitkovetsky trio takacs quartet angela hewitt piano cell duo nicolas altstaedt aleksandar mad ar
# 	 the season featured karin schaupp pavel steidl morgenstern trio christopher moore tokyo string quartet jian wang bernadette harvey elias string quartet angela hewitt academy ancient music sara macliver
# 	 the season featured tafelmusik diana doherty st lawrence string quartet trio dali tak cs quartet amarcord kuss quartet naoko shimizu anthony marwood aleksandar mad ar
#
# Cluster 290, #12 Elements
# 	 on november signing convention university paris ufe presence ufe former president tahani omar paris president jean charles pomerol french ambassador philippe coste
# 	 jacques lusseyran french author political activist world war ii ref
# 	 in end bitter political struggle included fran ois bayrou martine ligni res cassou became mayor pau
#
# Cluster 291, #12 Elements
# 	 sardar asgar nasir start working j p singh satya anand ramadhir singh son
# 	 sergeant christopher robert james thomas royal corps australian electrical mechanical engineers
# 	 ernest james coombes manager safety security barry factory bp chemicals
#
# Cluster 292, #12 Elements
# 	 edgar pearce rogers tawa private secretary ministers health
# 	 iris elsie storey telephonist naval ship production overseers office west midlands birmingham ministry defence
# 	 in president provincial council pedro escalante huidobro proposed reapplying name cantabria province santander suggested academic report written historian tom maza solano
#
# Cluster 293, #12 Elements
# 	 t film turned sleeper hit young working people sold
# 	 with cochin spice markets starved recent siege lopo soares sets collecting spices elsewhere
# 	 karen competent plankton formulating plots steal krabby patty recipe
#
# Cluster 294, #12 Elements
# 	 by end first world war hornsey borough council outgrown forty year old offices edge borough highgate
# 	 most chinese nationals renounce chinese nationality upon approval article except state functionaries active military personnel article
# 	 also spring gao huan gao cheng request made gao cheng eastern wei prime minister despite fact gao cheng point
#
# Cluster 295, #12 Elements
# 	 in fran ois bayrou became mayor standing david habib election
# 	 the vesnin brothers selected one thirteen teams invited third round palace soviets contest
# 	 in february cort went ahead anyway act open mutiny
#
# Cluster 296, #12 Elements
# 	 the cancer journals derived part personal journals written late seventies a burst light use non fiction prose preserve explore reflect lorde diagnosis treatment recovery breast cancer ref
# 	 jacob bolotin january april world first totally blind physician fully licensed practice medicine
# 	 following arrest solo sat one game reign ref nwsl allowed continue playing soccer end season ref
#
# Cluster 297, #12 Elements
# 	 converging cranganore portuguese cochinese vembanad fleet quickly disperses zamorin forces beach cannon fire lands amphibian assault force portuguese cochinese nairs take rest zamorin forces close combat
# 	 the first signs trouble assyrians started th century mongols first invaded near east fall baghdad hulagu khan ref
# 	 while complete details biblical account system fighting forms extant midrashic talmudic rabbinic accounts testify fighting combat strategies used ancient israelites well legendary depictions israelite combatants
#
# Cluster 298, #12 Elements
# 	 he member mental health taskforce ref chaired paul farmer led five year forward view psychiatry
# 	 stanley greenspan june april clinical professor psychiatry behavioral science pediatrics george washington university medical school practicing child psychiatrist
# 	 leo kanner pronounced conner june april jewish american psychiatrist physician known work related autism
#
# Cluster 299, #12 Elements
# 	 by law pennsylvania secondary school students required complete project part eligibility graduate high school
# 	 pennsylvania public school districts budget expend funds according procedures mandated general assembly pennsylvania department education pde
# 	 the act index regulates rates school district raise property taxes pennsylvania
#
# Cluster 300, #12 Elements
# 	 the theological foundation law
# 	 commander order isabella catholic spain ref
# 	 the free church england episcopal congregations
#
# Cluster 301, #12 Elements
# 	 a convention signed ufe ministry oil mars
# 	 since discovery beryllium used electronics ceramics research development labs aircraft atomic energy defense industry ref
# 	 le guin works set hainish universe explore idea human expansion theme found future history novels science fiction authors isaac asimov
#
# Cluster 302, #12 Elements
# 	 inspired life vienna enormous respect teacher simon pullman determined create pullman like ensemble sydney
# 	 kitchener promoted highest army rank field marshal september went tour australia new zealand ref
# 	 on october south island mayors led bob parker christchurch displayed united support southern mayoral council
#
# Cluster 303, #12 Elements
# 	 buhnemann notes deity mantras essential part tantric compendia
# 	 the fundamental principle sardar thought one way human
# 	 a a intelligence analysis assessments
#
# Cluster 304, #12 Elements
# 	 mukpo grew internationally whose father died lives ordinary secular life halifax nova scotia
# 	 gaston f bus descendant counts foix one first iconic figures b arn attached independence small country
# 	 the delaware river mill society private non profit organization responsible restoration maintenance operation historic john prall jr house prallsville mills complex listed national register historic places
#
# Cluster 305, #12 Elements
# 	 in tantric school universe sound
# 	 the ostau bearn pau organization bringing together practice teach language ref
# 	 the school regular fixture list major uk public schools
#
# Cluster 306, #12 Elements
# 	 the young turk revolution played significant role evolution committee union progress revolutionary organisation political party
# 	 many government expenditures shifted military budget
# 	 the housing finance act also brought fundamental changes rent legislation
#
# Cluster 307, #12 Elements
# 	 patrick andrew gallwey bantry wrote small cows district would produced half two thirds hundredweight butter per annum
# 	 with nearly billion sales arcos dorados represents percent mcdonald global sales ref
# 	 the sub national gdp south island estimated us billion new zealand national gdp ref
#
# Cluster 308, #12 Elements
# 	 mollie considered part east central indiana northern indiana
# 	 aarhus located bay aarhus facing kattegat sea east peninsulas mols helgen across bay northeast
# 	 western winds atlantic north sea dominant resulting precipitation western denmark
#
# Cluster 309, #12 Elements
# 	 the international airport pau pyr n es located north west commune uzein connected directly paris charles de gaulle paris orly well airports marseille lyon london southampton amsterdam among destinations
# 	 the city engaged bus haut niveau de service bus high level service bhns project first route railway station hospital
# 	 a tgv rail line runs paris bayonne toulouse
#
# Cluster 310, #12 Elements
# 	 improvements security tenure available occupants agricultural tied cottages made agriculture act
# 	 provision made landlords tenants regulated tenancies fair rent registered agree using special written agreement rent increases without reference rent officer without losing rights make future application fair rent determined
# 	 the housing act included provisions social rented sector houses multiple occupation administration housing benefit conduct tenants allocation housing local housing authorities homelessness
#
# Cluster 311, #12 Elements
# 	 the watts closely connected fowlers
# 	 chile top exports
# 	 the games popular
#
# Cluster 312, #12 Elements
# 	 in early several companies began experiment licensing less children oriented material
# 	 threaded dpc conversely ordinary dpc deferred procedure call decreases system latency improving performance time sensitive applications audio video playback
# 	 unit testing may reduce uncertainty units used bottom testing style approach
#
# Cluster 313, #12 Elements
# 	 the relative popularity beam deflection method explained high sensitivity simple operation fact cantilevers require electrical contacts special treatments therefore fabricated relatively cheaply sharp integrated tips
# 	 although peak forces applied contacting part oscillation much higher typically used contact mode tapping mode generally lessens damage done surface tip compared amount done contact mode
# 	 the effect printed music similar effect printed word information spread faster efficiently lower cost people could laboriously hand copied manuscripts
#
# Cluster 314, #12 Elements
# 	 in addition diphthongs triphthongs analyzed vowel nucleus plus semivowel coda followed final consonant
# 	 khmer phonation distinction vowels survives archaic dialect western khmer ref
# 	 nevertheless although predominantly christian minority assyrians still held onto ancient mesopotamian religion late th th century ad ref
#
# Cluster 315, #12 Elements
# 	 alternatively one think transactions terms monetary flows occur
# 	 households spend income y goods services consumption c
# 	 the median income household city median income family
#
# Cluster 316, #12 Elements
# 	 many methods beam deflection measurements exist
# 	 her conception many layers selfhood replicated multi genres work
# 	 online contracts become common
#
# Cluster 317, #12 Elements
# 	 amg mercedes benz house performance tuning division specialising high performance versions mercedes benz cars
# 	 juan manuel fangio five time formula world champion honorary president mercedes benz argentina death
# 	 mercedes benz produces range vans citan rebadged version renault kangoo vito sprinter
#
# Cluster 318, #12 Elements
# 	 the prince wales feathers heraldic badge prince wales sometimes adapted welsh bodies use wales
# 	 the process whereby indigenous population wales came think welsh clear
# 	 for speaking welsh important part welsh identity
#
# Cluster 319, #12 Elements
# 	 agriculture allied sectors like forestry logging fishing accounts gdp employed country labor force
# 	 chile position southern hemisphere leads agricultural season cycle opposite principal consumer markets primarily located northern hemisphere ref
# 	 looking collective family land one important responsibilities samoan families matai
#
# Cluster 320, #12 Elements
# 	 pau features wet mild winters warm mild summers drier
# 	 the iris foliage semi evergreen easy locate plant winter ref
# 	 the climate carr hill temperate like much north east england
#
# Cluster 321, #11 Elements
# 	 squadron leader lancelot john halvorson
# 	 lieutenant commander duncan fitzroy william honey died may
# 	 major quartermaster joshua guy brynolf the light infantry
#
# Cluster 322, #11 Elements
# 	 the first model system
# 	 butuan city known education competence
# 	 virgilio emmanuel zammit regents park new south wales
#
# Cluster 323, #11 Elements
# 	 the original order amendment made
# 	 pau located west toulouse tarbes lourdes oloron
# 	 the name town recorded th century
#
# Cluster 324, #11 Elements
# 	 john sanford mason august november career officer united states army served general union army american civil war
# 	 bob jones jr connoisseur european art began collecting world war ii year authorized university board directors ref
# 	 the lord kitchener memorial homes chatham kent built funds public subscription following kitchener death
#
# Cluster 325, #11 Elements
# 	 ten years later rousseau made inquiries fate son record could found
# 	 average price rent average apartment lausanne swiss francs chf per month us approx
# 	 the infantile form usually comes medical attention within first months life
#
# Cluster 326, #11 Elements
# 	 jenny mccarthy magazine later named playmate year
# 	 count jennifer lynn furminger last seen
# 	 on july bell announced retirement stating wished spend time new wife daughter
#
# Cluster 327, #11 Elements
# 	 the sensitivity piezoelectric materials decreases exponentially time
# 	 earlier generation displays circa prior phosphors lost luminosity time resulting gradual decline absolute image brightness
# 	 the sound never recovered setback although release mini album shock daylight live album in the hothouse two albums heads hearts thunder up next five years
#
# Cluster 328, #11 Elements
# 	 in october presidential elections fernando henrique cardoso elected votes
# 	 fcc spokesperson kim hart said ruling raise taxes fees
# 	 hedge fund manager mark spitznagel used weiqi main investing metaphor popular investing book the dao capital ref
#
# Cluster 329, #11 Elements
# 	 in overseas sector the main leakage sector imports m represent spending residents rest world
# 	 whilst early rules trade barter existed since ancient times modern laws contract west traceable industrial revolution onwards increasing numbers worked factories cash wage
# 	 sinatra became stereotype tough working class italian american something embraced
#
# Cluster 330, #11 Elements
# 	 peter kwong kong kit first archbishop primate hong kong sheng kung hui province retired end bishop emeritus diocese hong kong island hong kong sheng kung hui honorary doctor divinity university hong kong
# 	 ichiro married former tbs tv announcer ref december ref small church santa monica california
# 	 in book ii chapter church history eusebius describes death james according josephus
#
# Cluster 331, #11 Elements
# 	 buffalo m x liquid short lived oil based extinguishing agent magnesium fires made buffalo
# 	 a workers hut equipment durrus road railway station destroyed fire
# 	 when koombana berthed fremantle afternoon october end trip fire still smouldering
#
# Cluster 332, #11 Elements
# 	 most benefits three decades growth world war ii concentrated hands
# 	 taha hussein egyptian writer intellectual became blind age three
# 	 john mason one trusted men connecticut three half decades residence civil military matters
#
# Cluster 333, #11 Elements
# 	 lincoln child born author techno thriller horror novels ref
# 	 from distinction science fiction fantasy superhero films blurred thanks large part influence star wars
# 	 the science fiction comedy may finest hours woody allen sleeper dan o bannon dark star
#
# Cluster 334, #11 Elements
# 	 with americans increasing access digital age st century increasing amount individuals getting news social media becomes easy confuse fact fiction
# 	 since company become large supporter athletics sponsoring united states canadian olympic teams launching program offered employment athletes accommodates training competition schedules
# 	 in parramatta eels picked beginning year many leading betting agencies take premiership following surge form took grand final
#
# Cluster 335, #11 Elements
# 	 the financial success films relied studios drawing large teenage audiences taking advantage popular techniques drive theaters d notably used movies like the creature black lagoon gog ref
# 	 in bob jones iii became president age though father title chancellor continued exercise considerable administrative authority late ref
# 	 in job growth office construction spurred arrival national banks financial institutions wake financial center development act liberalized laws governing banks operating within state similar laws
#
# Cluster 336, #11 Elements
# 	 the ideology sandinistas put future private sector private ownership means production doubt
# 	 unlike many radical enlightenment philosophers rousseau affirmed necessity religion
# 	 in common philosophers day rousseau looked hypothetical state nature normative guide
#
# Cluster 337, #11 Elements
# 	 the voiced plosives pronounced implosives speakers feature weak educated speech become ref
# 	 the origin name uncertain
# 	 in situation phase current lags voltage
#
# Cluster 338, #11 Elements
# 	 mount vernon city schools operates elementary middle schools
# 	 in school inspected ofsted
# 	 irondequoit served west irondequoit east irondequoit central school districts
#
# Cluster 339, #11 Elements
# 	 the french comics anthology pilote published featured work adult oriented creators jean giraud moebius guido crepax caza american robert crumb
# 	 antarctic press founded publishes american manga independent creators notably terry moore strangers paradise
# 	 a book borland lyrics called adrian borland the sound meaning distant victory published giuseppe basile marcello nitti ref
#
# Cluster 340, #11 Elements
# 	 swedish chemist j ns jacob berzelius discovered chemical element named thor thorium ref
# 	 in the pyrene manufacturing company delaware filed patent using carbon tetrachloride ctc ccl extinguish fires ref
# 	 potassium bicarbonate urea complex aka monnex used class b c fires
#
# Cluster 341, #11 Elements
# 	 courts typically weigh adequacy consideration provided consideration determined sufficient sufficiency defined meeting test law whereas adequacy subjective fairness equivalence
# 	 f weak learner takes object x input returns value indicating class object
# 	 rousseau asserted stage human development associated called savages best optimal human development less optimal extreme brute animals one hand extreme decadent civilization
#
# Cluster 342, #11 Elements
# 	 the court may make order called specific performance requiring contract performed
# 	 a preliminary inquiry held testimony covered publication ban
# 	 public void testsumlargenumbers adder adder new adderimpl assert adder add
#
# Cluster 343, #11 Elements
# 	 in system announced support distributed data management architecture ddm
# 	 according united states census bureau town total area land water ref
# 	 paley public knowledge organization ip award work intellectual property ref
#
# Cluster 344, #11 Elements
# 	 according official statistics swedish speakers made total population finland million
# 	 some services sermons conducted irish c rev crosthwaite services attended thirty converts several poor protestants traveled six ten miles attend parish church
# 	 as united states census ref people households families residing borough
#
# Cluster 345, #11 Elements
# 	 applications field solid state physics include identification atoms surface b evaluation interactions specific atom neighboring atoms c study changes physical properties arising changes atomic arrangement atomic manipulation
# 	 based work kepler probably descartes leibniz develops model planetary motion based conatus principle idea aether fluid vortex
# 	 copper based copper powder navy s developed u s navy hard control lithium lithium alloy fires
#
# Cluster 346, #11 Elements
# 	 in june los angeles county metropolitan transportation authority approved million metro rail infill station called aviation th street construction crenshaw lax line connect automated people mover apm system called airport metro connector connecting terminals light rail systems ref
# 	 herbert alexander simon born milwaukee wisconsin june
# 	 the l structures downtown chicago replaced subway franklin van buren wabash randolph
#
# Cluster 347, #11 Elements
# 	 as census people households families residing town
# 	 as census ref people households families residing city
# 	 as census ref people households families residing city
#
# Cluster 348, #11 Elements
# 	 in audre lorde started visiting professorship west berlin free university berlin
# 	 japanese animation began early th century japanese filmmakers experimented animation techniques also pioneered france germany united states russia
# 	 the states santa catarina ref ref ref rio grande sul talian officially approved heritage language states ref esp rito santo pomeranian language along german language cultural heritage state ref
#
# Cluster 349, #11 Elements
# 	 the saw surge growth popularity manga japanese comic books graphic novels many later animated
# 	 jack holbrook vance highly prolific american master phantasy
# 	 the success science fiction films also saw genre grow internationally
#
# Cluster 350, #11 Elements
# 	 non contact mode afm suffer tip sample degradation effects sometimes observed taking numerous scans contact afm
# 	 command keys became rpg indicators ka ky different screen forms recognized different invisible control characters hidden forms
# 	 earlier generation displays susceptible screen burn image retention
#
# Cluster 351, #11 Elements
# 	 oem equipment must used replacement parts extinguisher maintain ul rating
# 	 it also essential implement sustainable process ensuring test case failures reviewed regularly addressed immediately ref
# 	 in hopes solidifying starting rotation team announced closer jonathan papelbon would become starter
#
# Cluster 352, #11 Elements
# 	 cummings made mark cbs radio network dramatic serial titled those we love ran
# 	 a composer demo original song found cd irving sings berlin
# 	 during early vedic period claims staal ref vedic poets became fascinated inspirational power poems metered verses music
#
# Cluster 353, #11 Elements
# 	 erik weihenmayer first blind person reach summit mount everest ref
# 	 the fifth installment espn full circle aired march nascar busch series race held autodromo hermanos rodriguez mexico city
# 	 the highlight mission first space walk american white remained tethered outside spacecraft minutes
#
# Cluster 354, #11 Elements
# 	 as early consulting engineer charles vignoles put forward scheme railway commission trunk line dublin cork including branch running blarney macroom glengarriff castletownebere
# 	 the second taw vale railway extension dock company
# 	 the original north devon line signalled using disc crossbar signals
#
# Cluster 355, #11 Elements
# 	 khmer verbs completely uninflected subject topic introduced clear context noun phrase may dropped
# 	 mutations exons rarely c kit gene known occur gist
# 	 reveries solitary walker trans
#
# Cluster 356, #11 Elements
# 	 there several different types damages
# 	 modern sheet music may come different formats
# 	 the type musical notation varies great deal genre style music
#
# Cluster 357, #11 Elements
# 	 the cup always greatly admired japan modernising called meiji restoration much impressed japan victory russia russian japanese war cup obsessed idea copying japanese
# 	 u s diplomats supported eu led dialogue beginning
# 	 initially rousseau pleased new accommodation wootton hall wrote favorably natural beauty place feeling reborn forgetting past sorrows ref
#
# Cluster 358, #11 Elements
# 	 the new form control relatively simple inflexible
# 	 body proportions human anime characters tend accurately reflect proportions human body reality
# 	 neurodiversity standpoint atypical neurological development normal human difference
#
# Cluster 359, #11 Elements
# 	 against air force notre dame next opponent montana entered game fourth quarter
# 	 saints one traditional big three rugby schools singapore along raffles anglo chinese ref
# 	 the wests tigers six appointed club captains one stage two co captains total first grade captains history
#
# Cluster 360, #11 Elements
# 	 psychedelic sluts erekta
# 	 bach flower remedies preparations devised edward bach tiny amounts plant material diluted mixture water brandy
# 	 alprazolam regular release orally disintegrating tablets available mg mg mg mg strength tablets ref
#
# Cluster 361, #11 Elements
# 	 dishes similar appearance taste preparation methods exist parts world well
# 	 the second season also attracted notable personalities
# 	 the verb ver become also commonly used meaning making lesser used mun vera bit stronger emphasis future english translation
#
# Cluster 362, #11 Elements
# 	 plain radiographs helpful evaluation gists
# 	 this something real true story i could tell way nobody else could
# 	 pitching remained strong pedro mart nez curt schilling tim wakefield
#
# Cluster 363, #11 Elements
# 	 onslow village sloped suburb western outskirts guildford
# 	 the tasman police district covers kilometres territory encompassing northern western portion south island
# 	 rouse classifies ta inhabitants greater antilles except western tip cuba bahamian archipelago northern lesser antilles
#
# Cluster 364, #11 Elements
# 	 gesar mukpo begins interviewing fellow canadian dylan henderson first caucasian tulku discovered west recognized ch gyam trungpa rinpoche incarnation one teachers
# 	 while pickton automatic right appeal supreme court canada based legal issues justice donald dissented pickton lawyers applied supreme court canada leave appeal issues well
# 	 the canadian institute gemmology cig career training institution gemmologists gem technologists canada
#
# Cluster 365, #11 Elements
# 	 john allman neuroscientist california institute technology pasadena california well recognized expert primates cognition evolutionary neuroscience
# 	 dr willie smits rainforest inventor revolutionized reforestation techniques policies worldwide also world prominent protector orangutans natural habitat
# 	 puerto ricans empire provides excellent introduction puerto rico crucial tobacco industry fascinating material farmer organizations agricultural research
#
# Cluster 366, #11 Elements
# 	 the watts family also strongly connected beale family
# 	 the surface cantilevers also modified
# 	 prohibitives take form v also often softened addition particle end phrase ref
#
# Cluster 367, #11 Elements
# 	 plasma displays bright lux higher module wide color gamut produced fairly large sizes diagonally
# 	 there heavy presence fabulous beings giant proportions cyclopean features oj ncanos fantastic animals culebres caballucos del diablu lit
# 	 the chamber monument measures metres feet length metres feet inches width although potentially much larger originally constructed
#
# Cluster 368, #11 Elements
# 	 the mp brent north barry gardiner said community involvement far prevented riots ref
# 	 his calm attitude patient questions ability tease substance nebulous statements callers guests gave show relaxed yet serious atmosphere
# 	 due gulf stream cantabria well rest green spain much temperate climate might expected latitude comparable oregon
#
# Cluster 369, #11 Elements
# 	 according census people brazil
# 	 b foreigners nationality resident federative republic brazil fifteen uninterrupted years without criminal conviction provided apply brazilian nationality
# 	 ii registered permanent resident brazil
#
# Cluster 370, #11 Elements
# 	 in southern california brush mice captured leaf mold oak hardwood association coast live oak white alder alnus rhombifolia whiteflower currant sumac rhus spp ref
# 	 vegetation brush mouse habitats may vary location location brush mice consistently captured areas medium high densities shrubs tree cover ft height ref
# 	 brush mice also commonly captured locations high proportions rock cover slash piles habitats characterized chaparral mountain shrub oak shrub oak juniper pinyon pine juniper pinyon pine oak pine communities well riparian habitats ref
#
# Cluster 371, #10 Elements
# 	 flight sergeant roger wilfred louis f
# 	 flight lieutenant john jeffrey wilkinson
# 	 squadron leader ian murray calder
#
# Cluster 372, #10 Elements
# 	 in rexroth wrote encyclop dia britannica article literature
# 	 elisabeth muriel pring foreign commonwealth office
# 	 muriel audrey rust personal assistant hm embassy rabat
#
# Cluster 373, #10 Elements
# 	 it possible sue crown uk breach contract
# 	 an exception arises advertisement makes unilateral promise offer reward famous case carlill v carbolic smoke ball company ref decided nineteenth century england
# 	 in started new comic strip mimi eunice highlighting intellectual property problems paradoxes
#
# Cluster 374, #10 Elements
# 	 in wessely elected president royal college psychiatrists
# 	 j rn donner writer film director actor producer politician
# 	 bcs governed trustee board comprising president deputy president immediate past president nine vice presidents including vice president finance five professional members elected advisory council ref
#
# Cluster 375, #10 Elements
# 	 thomas henry dickinson receptionist head office british steel corporation
# 	 a first defensive tower desired castle gaston f bus called tour du moulin tower mill time built along water channel operating mill castle early th century
# 	 the site fortified th century ref control ford across gave de pau
#
# Cluster 376, #10 Elements
# 	 it presented neves opposition candidate paulo maluf ref
# 	 harvey alper ref others ref present linguistic view mantras
# 	 the word dharani derives sanskrit root dh r means hold maintain
#
# Cluster 377, #10 Elements
# 	 ibm a dot matrix printer rated lpm
# 	 ibm a dot matrix printer rated lpm
# 	 ibm a dot matrix printer rated lpm
#
# Cluster 378, #10 Elements
# 	 a gang heavily armed men scour finally narrow house wasseypur
# 	 a large furniture shop house reeves croydon since ref ref burned ground ref
# 	 photos contents garbage found pickton slaughterhouse held remains mona wilson
#
# Cluster 379, #10 Elements
# 	 ssp system support program operating system s
# 	 by time albrecht gained sympathy koombanas crew
# 	 he subsequently decided accept hume invitation england ref
#
# Cluster 380, #10 Elements
# 	 ma eligible second term president ran election
# 	 california celebrates john muir day april year
# 	 on april felix schlag announced winner
#
# Cluster 381, #10 Elements
# 	 captain adviser infantry weapons alexander wilson small arms school corps
# 	 pun chak yu senior superintendent police royal hong kong police force
# 	 sergeant meherman limbu th princess mary own gurkha rifles
#
# Cluster 382, #10 Elements
# 	 hearing attack zamorin dispatched hastily formed calicut fleet ships paraus save city
# 	 the nd india armada pedro lvares cabral opened hostilities kingdom portugal zamorin king calicut calecute kozhikode dominant maritime power malabar coast india
# 	 when order koombana placed adelaide steamship company major operator coastal shipping fremantle western australia northern ports
#
# Cluster 383, #10 Elements
# 	 as modern machines computer printers made s era slow point possible s computers write data printer faster print
# 	 pruning refers process removing poorly performing weak classifiers order improve memory execution time cost boosted classifier
# 	 green increasing fame made harder ambush people man street segments leading target mostly senior citizens non english speakers
#
# Cluster 384, #10 Elements
# 	 anime art form specifically animation includes genres found cinema mistakenly classified genre
# 	 borland initial influences traced work the outsiders punk bands sex pistols
# 	 shyft introduced whirlwind expansion strange reptilian creatures seemed strange psychic bond various mage spawn found land
#
# Cluster 385, #10 Elements
# 	 splinter mutant rat sensei adoptive father ninja turtles trained ninjutsu owner master hamato yoshi japan
# 	 as splinter owner yoshi greatest shadow warrior foot clan japan trained splinter art ninjutsu allowing rat copy katas inside cage
# 	 in idw comics slash introduced specimen snapping turtle experiment stockgen mutated old hob dna assigned hunt ninja turtles splinter
#
# Cluster 386, #10 Elements
# 	 the coldrum stones excavated multiple occasions
# 	 ashbee suggested given size comparisons long barrows fussell lodge coldrum tomb could housed remains hundred individuals
# 	 this phase rehabilitation program weeks surgery
#
# Cluster 387, #10 Elements
# 	 wessely believes cfs generally organic trigger virus role psychological social factors important perpetuating illness otherwise known cognitive behavioural model cfs treatments centred around factors effective
# 	 vaccine adverse event reporting system united states program vaccine safety co managed centers disease control prevention cdc food drug administration fda
# 	 di bella therapy cocktail vitamins drugs hormones devised luigi di bella promoted cancer treatment
#
# Cluster 388, #10 Elements
# 	 one first shopping carts introduced june invention sylvan goldman owner humpty dumpty supermarket chain oklahoma
# 	 adam gardner born singer songwriter guitarist band guster grew morristown ref
# 	 wjsv radio fm nonprofit radio station morristown high school also television show airs colonial corner
#
# Cluster 389, #10 Elements
# 	 ames headquarters iowa department transportation ref
# 	 john cabot road north phoenix arizona
# 	 in many years advocacy white others northern state normal school northern michigan university opened ref
#
# Cluster 390, #10 Elements
# 	 the third expedition columbus beginning first successful castilian spanish colonization west indies island hispaniola
# 	 in expedition sent spanish crown find way asia led experienced portuguese navigator ferdinand magellan
# 	 in cuba governor diego vel zquez de cu llar commissioned fleet command hern ndez de c rdoba explore yucat n peninsula
#
# Cluster 391, #10 Elements
# 	 morristown located th congressional district ref part new jersey th state legislative district ref
# 	 during protestant reformation municipalities converted new faith
# 	 children born saybrook connecticut rachel b ann b daniel b elizabeth born stonington connecticut
#
# Cluster 392, #10 Elements
# 	 church christ china
# 	 presbyterian church korea koshin kosin
# 	 union evangelical congregational churches macedonia
#
# Cluster 393, #10 Elements
# 	 according the heritage foundation index economic freedom chile strongest private property rights latin america scoring scale
# 	 the main taxes chile terms revenue collection value added tax total revenues income tax total revenues ref
# 	 chile monetary authority central bank chile cboc
#
# Cluster 394, #10 Elements
# 	 windows vista also includes new multimedia class scheduler service mmcss allows multimedia applications register time critical processing run elevated thread priority thus ensuring prioritized access cpu resources time sensitive dsp processing mixing tasks
# 	 the equal treatment law expanded responsibility ombudsman ensure equal opportunity workplace regardless ethnic origin religion age sexual orientation address general discrimination ethnic origin
# 	 the ideal pcba manufacturing test covers successfully detects defect present entire pcba manufacturing test defect universe
#
# Cluster 395, #10 Elements
# 	 alexander ramsay process foreman non tech
# 	 cabot first voyage little recorded
# 	 murdoch explores city nobody realizes always nighttime
#
# Cluster 396, #10 Elements
# 	 the principles aerodynamic lift shared nature man made aircraft
# 	 pau part global competitiveness cluster aerospace valley aerospace sector toulouse bordeaux
# 	 lausanne airport located bl cherette also houses boeing simulator ref
#
# Cluster 397, #10 Elements
# 	 the primary purpose csp keep msp busy ran slightly x speed msp
# 	 superfetch caches frequently used applications documents memory keeps track commonly used applications usually loaded pre cached also prioritizes programs currently used background tasks
# 	 the offline files feature maintains client side cache files shared network significantly improved
#
# Cluster 398, #10 Elements
# 	 by replying message after aligning forms operator could sure check information print forms properly aligned
# 	 proponents net neutrality see important component open internet policies equal treatment data open web standards allow using internet easily communicate conduct business activities without interference third party ref
# 	 the law provides citizens right change government peacefully citizens exercised right practice periodic free fair elections held basis universal suffrage
#
# Cluster 399, #10 Elements
# 	 owing overwhelming success many different manufacturers desired produce shopping carts rear swinging door feature denied due exclusive license issued goldman
# 	 the race saw ren dreyfus delahaye sensationally beating mercedes benz team
# 	 in addition corporate support olympic committee also made use burgeoning prices paid exclusive television rights
#
# Cluster 400, #10 Elements
# 	 before th century western music written hand preserved manuscripts usually bound large volumes
# 	 the cup built extensive organisation presence towns capital throughout europe
# 	 immigration also became urban phenomenon immigrants came cities even descendants immigrants previous periods moving intensely countryside
#
# Cluster 401, #10 Elements
# 	 after july monarchy pau became famous climate sports resort western europe
# 	 meanwhile dr kennard said ban would effective public events sports day speech day
# 	 dominica clean green country hydro currently powers dominica electricity sector solar energy becoming increasingly popular island geothermal energy growing ref
#
# Cluster 402, #10 Elements
# ...
#
# Cluster 1201, #5 Elements
# 	 khmer primarily analytic language inflection
# 	 in danish future usually unmarked using present tense form
# 	 sections caps include word breather titles normal title case mostly straightforward narrations intricately plotted intimately related difficult portions
#
# Cluster 1202, #5 Elements
# 	 afforestation projects undertaken prevent groundwater pollution secure drinking water sequester co increase biodiversity create attractive countryside provide easy access nature offer outdoor activities public
# 	 muir called patron saint american wilderness archetypal free spirit
# 	 muir exalted wild nature human culture civilization believing life sacred
#
# Cluster 1203, #5 Elements
# 	 in developing miami beach potential resort hotels fisher needed transportation connection mi fec railroad station miami ref
# 	 while organization called longer club still clubhouses south america
# 	 the home depot began branch georgia florida stores opening hollywood ft
#
# Cluster 1204, #5 Elements
# 	 during washington second stay march declared st patrick day holiday honor many irish troops ref
# 	 schools knockroe gearhies gortalassa employed irish speaking teachers including seamus o suilleabhain ui shuilleabhain fachdnaidh bonane near kenmare
# 	 scottish gaelic celtic language native scotland
#
# Cluster 1205, #5 Elements
# 	 most countries world require regular fire extinguisher maintenance competent person operate safely effectively part fire safety legislation
# 	 internationally several accepted classification methods hand held fire extinguisher
# 	 there several class d fire extinguisher agents available handle multiple types metals others
#
# Cluster 1206, #5 Elements
# 	 there three types viral infections considered topic viral transformation
# 	 there two types cytocidal infections productive abortive
# 	 viral transformation impose characteristically determinable features upon cell
#
# Cluster 1207, #5 Elements
# 	 accommodation provided first second saloon passengers style otherwise found much larger vessels ref
# 	 there lakes new zealand surface area larger one hectare
# 	 buildings typically circular diameters meters walls cm thick
#
# Cluster 1208, #5 Elements
# 	 ma performed duet condoleezza rice presentation national medal arts national humanities medal awards
# 	 there cure berylliosis
# 	 the zodiac found mediaeval stained glass angers cathedral master glassmaker andr robin made ornate rosettes north south transepts fire ref
#
# Cluster 1209, #5 Elements
# 	 a cr perie may takeaway restaurant stall serving cr pes form fast food street food may formal sit restaurant caf ref
# 	 welfare committee provides welfare services lunch box service sale school sweaters old books stationery
# 	 on february haltzman robbins counsel told msnbc live robbins sitting home eating mike ike candy front school issued laptop ref
#
# Cluster 1210, #5 Elements
# 	 satellite television provider astro provides several tamil satellite television channels
# 	 cable television system broadcasting television programming paying subscribers via radio frequency rf signals transmitted coaxial cables light pulses fiber optic cables
# 	 the abbreviation catv often used cable television
#
# Cluster 1211, #5 Elements
# 	 in s paulo twice many italians brazilians city
# 	 most poles immigrated brazil german russian austro hungarian austrian passports ukrainians austrian passports hungarians romanian passports
# 	 most immigrants levant included orthodox greeks lebanon ottoman greeks carried ottoman passports
#
# Cluster 1212, #5 Elements
# 	 autumn view estates a neighborhood private road along bayshore blvd
# 	 carr hill modern populous village ref situated hill still isolated gateshead felling ref
# 	 as third irvington land undeveloped public land ref percent land irvington set aside parks recreation ref
#
# Cluster 1213, #5 Elements
# 	 there representative governing bodies greek community cal state la interfraternity council national pan hellenic council multi cultural greek council panhellenic council
# 	 zeta beta tau phi sigma kappa sigma nu sigma alpha epsilon internationally recognized social fraternities university
# 	 alpha phi alpha historically black greek letter fraternity cal state la campus citywide chapter
#
# Cluster 1214, #5 Elements
# 	 in green released milk stout beer beau all natural brewing company called the tom green beer
# 	 alprazolam oral solutions available mg ml mg ml oral solutions
# 	 in vitro alprazolam bound percent human serum protein
#
# Cluster 1215, #5 Elements
# 	 pang shuk keung chief meter reader water supplies department hong kong
# 	 according accounts captives provided shared buckets use toilets access running water ref
# 	 water resistance models consist paddle revolving enclosed tank water
#
# Cluster 1216, #5 Elements
# 	 like many egyptian private universities ufe joint curricula french counterparts
# 	 harris like many anthropologists looking anthropological method data use term anthropology little difficulty finding among ancient authors
# 	 in countries british commonwealth social anthropology often institutionally separate physical anthropology primatology may connected departments biology zoology archaeology may connected departments classics egyptology like
#
# Cluster 1217, #5 Elements
# 	 the canton aargau one least mountainous swiss cantons forming part great table land north alps east jura rise low hills
# 	 thunnus widely sparsely distributed throughout oceans world generally tropical temperate waters latitudes ranging north south equator ref
# 	 the marquesas islands group one remote world lying northeast tahiti away west coast mexico nearest continental land mass
#
# Cluster 1218, #5 Elements
# 	 pau also green city occupied green areas many rare exotic species
# 	 the botanical garden d sseldorf scientific institution hhu cultivates different kinds plants around globe
# 	 nepenthes rajah like virtually species genus scrambling vine
#
# Cluster 1219, #5 Elements
# 	 morristown attempted implement transit oriented development
# 	 the solution developed miami beach railway electric street railway system served additional purpose providing electric service
# 	 perhaps high profile public project awarded vesnins design paveletskaya radialnaya station moscow metro
#
# Cluster 1220, #5 Elements
# 	 a balloon bag filled gas lower density surrounding air provide buoyancy
# 	 gliding flight requires initial launch giving object enough energy fly
# 	 if air rising faster object descending carried upwards
#
# Cluster 1221, #5 Elements
# 	 the town guildford forms part larger area administered borough guildford turn forms part county surrey
# 	 although guildford historically county town surrey council administrative base kingston upon thames ref although formerly surrey greater london
# 	 the campus university surrey guildford
#
# Cluster 1222, #5 Elements
# 	 bus services guildford primarily operated arriva additional services buses excetera safeguard stagecoach
# 	 as main railway station across river bus station small proportion bus services stop railway station ref
# 	 the closest bus stops terminals pair opposites sepulveda boulevard century boulevard served metro torrance metro commuter express metro los angeles union station owl service
#
# Cluster 1223, #5 Elements
# 	 oglethorpe plan called six wards squares
# 	 the city divided quartiers districts sometimes composed several neighborhoods
# 	 the marquesas islands subdivided six communes municipalities
#
# Cluster 1224, #5 Elements
# 	 many native scholars early th century led monk named chuon nath resisted french thai influences language
# 	 classifying particles used numerals always obligatory thai chinese example often dropped colloquial speech
# 	 a good number tamil inscriptions well hindu buddhist icons emanating south india found southeast asia even parts south china
#
# Cluster 1225, #5 Elements
# 	 prallsville mills become place cultural environmental events attracting widespread participation
# 	 in later years used metaphor nature home writings promote wilderness preservation ref
# 	 soldotna creek park contains river access amphitheater community playground picnic pavilions restrooms open green spaces
#
# Cluster 1226, #5 Elements
# 	 as larger communities texas gambling prostitution common galveston th century
# 	 even vice red light districts shut texas cities galveston vice based tourism continued thrive
# 	 gambling popular pastime many parts early mexico including northern territory texas ref
#
# Cluster 1227, #5 Elements
# 	 in spite parliamentary elections non partisan figures pre revolutionary period known old turks still dominated ottoman cabinet known sublime porte
# 	 in presidential election ma remained loyal kmt supported candidate lien chan james soong bolted party running independent ref
# 	 former presidents mexico continue carry title president death rarely referred commonly called ex presidents
#
# Cluster 1228, #5 Elements
# 	 chile great diversity natural landscapes mars like landscapes hyperarid atacama desert glacier fed fjords chilean patagonia passing winelands backdropped andes central valley old growth forests lakes district
# 	 durand eastman park a large park geographically surrounded town three sides lake ontario
# 	 a number lakes fiordland otago regions also fill glacial valleys
#
# Cluster 1229, #5 Elements
# 	 the following ed resolutions common prior introduction hd displays long phased favor hd displays well overall pixel count ed displays lower pixel count sd pal displays x vs x respectively
# 	 plasma displays different liquid crystal displays lcds another lightweight flat screen display using different technology
# 	 until early plasma displays popular choice hdtv flat panel display many benefits lcds
#
# Cluster 1230, #5 Elements
# 	 outside rodeo world disagreement exactly rodeo
# 	 rodeos may also offer western themed entertainment intermission including music novelty acts trick riding
# 	 outside competitive events activities often associated rodeos particularly local levels
#
# Cluster 1231, #5 Elements
# 	 dog river rouleau saskatchewan population according census sensibility
# 	 corner gas online provides cast biographies episode synopsis bloopers visit virtual dog river
# 	 the havanese member bichon family dogs
#
# Cluster 1232, #5 Elements
# 	 injections leakages
# 	 the water comes deep source surface appearance springs differed
# 	 eddy creek experiences total flow loss ref
#
# Cluster 1233, #5 Elements
# 	 other businesses mollie included general store cider mill blacksmith shop
# 	 some retailers target begun using carts fully made recycled plastic metal part wheel axles drawing away established metal cart design
# 	 another shopping cart innovator orla watson ref invented swinging rear door allow nesting ref
#
# Cluster 1234, #5 Elements
# 	 there also many private schools chitr including colegio agustiniano roman catholic private school international saint george school
# 	 each province deals differently private religious schools
# 	 many canadians remain polarized issue permitting private universities canadian market
#
# Cluster 1235, #5 Elements
# 	 ravindra jain indian poet musician composed several superhit hindi film songs
# 	 deepavali popularly known festival lights another major hindu festival celebrated hindu communities
# 	 bharata natyam tamil classical dance india important feature tamil culture hence popular malaysia
#
# Cluster 1236, #5 Elements
# 	 in recent past contributed regular column loksatta marathi titled badalate vishwa badalata bharat ref vishwachi maze ghar ref sakal
# 	 contributed articles hindi daily dainik bhaskar
# 	 he written several features human interest stories several journals periodicals etc english japanese marathi sakal lokmat maharashtra times antarnad sadhana etc ref
#
# Cluster 1237, #5 Elements
# 	 the city major agricultural produce rice bananas coconuts poultry shrimp milkfish
# 	 by end th century entire economy came resemble often referred banana republic economy one controlled foreign interests small domestic elite oriented toward production single agriculture export
# 	 bananas agriculture dominate dominica economy nearly one third labour force works agriculture
#
# Cluster 1238, #5 Elements
# 	 wmtr am radio station khz licensed morristown
# 	 danmarks radio large department aarhus employees
# 	 wmix am am frequency radio station operating within city owned withers broadcasting
#
# Cluster 1239, #5 Elements
# 	 smits received first non indonesian satya lencana pembangunan award
# 	 i jg consisted one headquarters flight gruppenstab staffels
# 	 wing commanders originally jg formed single group i jg
#
# Cluster 1240, #5 Elements
# 	 the national domain ch teau de pau composed renaissance garden medicinal plants park
# 	 milk thistle silybum marianum biennial plant grows many locations word
# 	 it grows alpine pastures meadows slopes ref
#
# Cluster 1241, #5 Elements
# 	 the monument originally consisted sarsen stone chamber covered low earthen mound bounded prostrate slabs
# 	 it built using stones
# 	 the earthen mound covered tomb visible undulation approximately foot inches height
#
# Cluster 1242, #5 Elements
# 	 the havanese dark brown eyes almond shaped lids surrounded black pigment
# 	 the stanley shale predominantly clayey thinly fissile black green shale large amounts sandstone interbedded throughout formation
# 	 the hot springs sandstone member stanley shale hereafter referred hot springs sandstone consists fine medium grained sandstone shale conglomerate
#
# Cluster 1243, #5 Elements
# 	 in southern brazil immigrants settled col nias colonies rural areas composed many small farms settled families
# 	 muir built small cabin along yosemite creek ref designing section stream flowed corner room could enjoy sound running water
# 	 it small village centre parade shops village hall
#
# Cluster 1244, #5 Elements
# 	 the identities models native american obverse bison reverse known certainty
# 	 allen memorial art museum oberlin college oberlin ohio
# 	 museum contemporary native arts contemporary native american arts political aspects
#
# Cluster 1245, #5 Elements
# 	 with denver club headquarters lima clubhouse became resource members travels
# 	 during time shining path active peru saec served source information safety areas country ref
# 	 after shining path leader abimael guzm n captured peruvian police country became safer travel
#
# Cluster 1246, #5 Elements
# 	 for example parallelogram subdivided trapezoid right triangle shown figure left
# 	 for circle ratio area circumference term perimeter circle equals half radius r
# 	 the main idea bentley ottmann algorithm use sweep line approach vertical line l moves left right across plane intersecting input line segments sequence moves ref
#
# Cluster 1247, #5 Elements
# 	 gia also designs manufactures professional equipment grading identifying selling diamonds colored gemstones
# 	 in addition basic jeweler tools loupes tweezers gem cloths gia instruments product catalog includes sophisticated instruments ranging microscopes spectroscopes
# 	 additionally gia carlsbad campus offers several programs jewelry arts
#
# Cluster 1248, #5 Elements
# 	 friends blue mountain
# 	 fold flag lengthwise blue field outside
# 	 in rondo blood carmilla blue haired companion called
#
# Cluster 1249, #5 Elements
# 	 population male female
# 	 population male female
# 	 population male female
#
# Cluster 1250, #5 Elements
# 	 harold charles nightingale lately head gardener royal automobile club country club woodcote park epsom
# 	 cabot links golf course inverness nova scotia
# 	 parkside whispering pines oldest miniature golf course still existence
#
# Cluster 1251, #5 Elements
# 	 elizam escobar painter activist
# 	 soraida martinez contemporary painter known creating socially conscious verdadism art style since
# 	 santa fe also contains lively contemporary art scene meow wolf main art collective
#
# Cluster 1252, #5 Elements
# 	 exercises strengthen muscles around knee especially quadriceps
# 	 persistent significant swelling stiffness knee
# 	 the force distribution across knee joint increasing force concentration cartilage joint structures

# %%
cluster_list1 = []
for i, cluster in enumerate(clusters1):
  cluster_list1.append(cluster)

# %%
sen1 = []
for i, cluster in enumerate(clusters1):
  for id in cluster[:]:
    sen1.append([i, training_data[id]])

# %%
df1=pd.DataFrame(sen1,columns=['cluster_no','sentences'])

# %% [markdown]
# ### Saving the csv file of clustering

# %%
df1.to_csv('cluster_using_Siamese_BERT-Networks.csv')

# %% [markdown]
# ### Sentence Embeddings Elmo, loading the model

# %%
corpus1 = corpus[:8000]
corpus1['Text'] = corpus1['Text'].replace(np.nan, '')
corpus1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                    Text
# 0     moeller student run newspaper the crusader con...
# 1     in the crusader first place second highest hon...
# 2     the squire student literary journal features s...
# 3     paul keels play play announcer ohio state univ...
# 4                       joe uecker ohio state senator r
# ...                                                 ...
# 7995                               the presence kingdom
# 7996                             false presence kingdom
# 7997                 ex g se des nouveaux lieux communs
# 7998                      the politics god politics man
# 7999                                   the meaning city
#
# [8000 rows x 1 columns]

# %%
training_data1 = corpus1["Text"]
training_data1 = list(training_data1)

# %%
elmo_url = "https://tfhub.dev/google/elmo/3"
embed = hub.KerasLayer(elmo_url)

# %%
embedded_lines = []
for line in corpus1.values:
    embedded_line = embed(np.array(line))
    embedded_lines.append(embedded_line)

# %%
embedded_lines

# %%
len(embedded_lines)
# Out:
# 8000

# %%
with open('sentence_embeddings_elmo.pickle', 'wb') as handle:
    pickle.dump(embedded_lines, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('sentence_embeddings_elmo.pickle', 'rb') as handle:
    embedded_lines = pickle.load(handle)

# %%
embedded_lines = np.vstack(embedded_lines)

# %%
embedded_lines = np.array(embedded_lines)

# %% [markdown]
# ### Clustering results

# %%
clusters2 = cluster_detection(embedded_lines, min_community_size=5, threshold=0.65)

# %%
for i, cluster in enumerate(clusters2):
    print("\nCluster {}, #{} Elements ".format(i+1, len(cluster)))
    for sentence_id in cluster[0:3]:
        print("\t", training_data[sentence_id])
# Out:
# Cluster 1, #2522 Elements
# 	 paul keels play play announcer ohio state university football basketball wbns fm
# 	 joe uecker ohio state senator r
# 	 rico murray undrafted free agent signee cincinnati bengals
#
# Cluster 2, #621 Elements
# 	 moeller high school athletic teams exception boxing lacrosse skiing volleyball sanctioned ohio high school athletic association ohsaa compete greater catholic league south along elder st xavier la salle high schools
# 	 the watts family one central families introduced viewers eastenders began created show co creators tony holland julia smith
# 	 the callen lorde community health center organization new york city named michael callen audre lorde dedicated providing medical health care city lgbt population without regard ability pay
#
# Cluster 3, #207 Elements
# 	 quite number countermeasures installed counteract misuse computers including web filtering monitor students use computers
# 	 the abstraction ignores linear throughput matter energy must power continuous motion money goods services factors production
# 	 the common method cantilever deflection measurements beam deflection method
#
# Cluster 4, #157 Elements
# 	 the small east central indiana village named mollie located harrison township section blackford county intersection county roads north east ref
# 	 other contributors mollie demise concerned jacob burnworth tile factory
# 	 western khmer also called cardamom khmer chanthaburi khmer spoken small isolated population cardamom mountain range extending western cambodia eastern central thailand
#
# Cluster 5, #109 Elements
# 	 the circular flow income concept better understanding economy whole example national income product accounts nipas
# 	 the circular flow diagram illustrates interdependence flows activities occur economy production goods services output economy income generated production
# 	 knowledge interdependence circular flow income signifies interdependence activity upon one another
#
# Cluster 6, #100 Elements
# 	 when opened doors moeller high school received students parishes northeastern part greater cincinnati area drawing roger bacon high school purcell marian high school two male comprehensive cincinnati archdiocesan schools
# 	 mollie considered part east central indiana northern indiana
# 	 since musica viva in schools inspiring children think actively listen create music bringing professional live music performances primary secondary schools australia
#
# Cluster 7, #79 Elements
# 	 the importance vic watts became obvious sharon returned lay claim pub year absence
# 	 soon den joined second wife chrissie pair proceeded bring whole mitchell financial empire bankrupting family scam retaking control vic
# 	 in late us department justice ended case ibm ibm went forward system named as
#
# Cluster 8, #78 Elements
# 	 from lorde brief affair sculptor painter mildred thompson
# 	 sinatra judy garland remained good friends death two occasions two legendary singers romantically involved
# 	 august lopo soares leaves mozambique
#
# Cluster 9, #64 Elements
# 	 the audre lorde award annual literary award presented publishing triangle honor works lesbian poetry first presented
# 	 nominated national book award poetry from land where other people live broadside press shows lorde personal struggles identity anger social injustice
# 	 with strong ideology open mindedness lorde impact lesbian society also significant
#
# Cluster 10, #62 Elements
# 	 however popularity watts viewers importance family show meant successive producers executives continually asked dean dobson grantham reprise roles ref
# 	 saibal chatterjee ndtv gave movie stars concluding it may faint hearted prissy
# 	 the film mainly draws story real life gang wars took place region dhanbad jharkhand
#
# Cluster 11, #61 Elements
# 	 contrary audre lorde open sexuality sexual awakening
# 	 khmer verbs relatively open class divided two types main verbs auxiliary verbs ref
# 	 the khmer particle marked attributes old khmer noun phrases used formal literary language signify precedes noun follows attribute
#
# Cluster 12, #59 Elements
# 	 throughout years screen watts one eastenders tried tested sources drama tragedy
# 	 the christmas day episode den delivered angie divorce papers highest rated airing british soap television history
# 	 much drama watts household centres responses den selfish actions manipulative ways
#
# Cluster 13, #59 Elements
# 	 in terms five sector circular flow income model state equilibrium occurs total leakages equal total injections occur economy
# 	 when direct object indirect object present without grammatical markers preferred order sv do io
# 	 a new attorney discipline system went effect january designed improve effort protect client rights guarantee lawyers full fair evaluation complaints
#
# Cluster 14, #58 Elements
# 	 the moeller art program nationally recognized four year program culminates advanced placement studio art art history ref
# 	 the cancer journals derived part personal journals written late seventies a burst light use non fiction prose preserve explore reflect lorde diagnosis treatment recovery breast cancer ref
# 	 nasir narration describes history nature wasseypur
#
# Cluster 15, #56 Elements
# 	 mollie post office established october
# 	 orchid boat seabury press
# 	 a second committee set viscount ridley review working rent restriction acts formed favourable opinion rent furnished houses control scotland act recommended england wales follow suit
#
# Cluster 16, #53 Elements
# 	 as adopted mother stepmother angie chrissie fiercely protective charges
# 	 in general court established statute unified court system making chief justice supreme court responsible efficient operation courts new hampshire
# 	 in united kingdom courts determine whether term condition warranty example actress obligation perform opening night theatrical production condition ref singer obligation rehearse may warranty ref
#
# Cluster 17, #51 Elements
# 	 ct scanning often undertaken see radiology section
# 	 as tumor grows may project outside bowel exophytic growth inside bowel intraluminal growth commonly grow exophytically bulk tumor projects abdominal cavity
# 	 gists tumors connective tissue e sarcomas unlike gastrointestinal tumors non epithelial
#
# Cluster 18, #48 Elements
# 	 second taxes productive classes farmers reduced favor higher taxes unproductive classes landowners since luxurious way life distorts income flow
# 	 unending nature economic activities it signifies production income expenditure unending nature therefore economic activities economy never come halt
# 	 lorde identified issues class race age gender even health last added battled cancer later years fundamental female experience
#
# Cluster 19, #44 Elements
# 	 after wedding ceremony royal procession heading back royal palace assassination attempt made king queen
# 	 in orla watson devised system telescoping e nesting shopping cart require assembly disassembly parts use like goldman cart goldman design point required cart unfolded much like folding chair ref
# 	 door rahila gaon one poem stretches stanzas rhyme
#
# Cluster 20, #44 Elements
# 	 the rent act introduced rent officer service
# 	 in practice matters delegated senior rent officer seventy seven original registration area offices
# 	 the leasehold reform act brought back acts long tenancies tenancy granted term years certain exceeding twenty one years low rent unintentionally applied rent act inhibitions upon premiums
#
# Cluster 21, #41 Elements
# 	 an important development john maynard keynes publication general theory employment interest money
# 	 a review chairmanship hugh francis qc commissioned october review operation rent regulation rent acts especially large centres population accommodation scarce consider relationship furnished unfurnished codes
# 	 stanley greenspan june april clinical professor psychiatry behavioral science pediatrics george washington university medical school practicing child psychiatrist
#
# Cluster 22, #37 Elements
# 	 in government sector the leakage government sector provides collection revenue taxes t provided households firms government
# 	 it also administration many state owned companies privatized agencies created first time regulate many sectors industry energy oil aviation etc
# 	 the supreme court jurisdiction review appeals state trial courts many state administrative agencies
#
# Cluster 23, #35 Elements
# 	 in financial sector in terms circular flow income model leakage financial institutions provide economy option households save money
# 	 the afm operated number modes depending application
# 	 in british supermarket chain tesco trialed shopping carts user adjustable wheel resistance heart rate monitoring calorie counting hardware effort raise awareness health issues
#
# Cluster 24, #35 Elements
# 	 the city major agricultural produce rice bananas coconuts poultry shrimp milkfish
# 	 the pickton brothers gradually neglected site farming operations
# 	 pau features wet mild winters warm mild summers drier
#
# Cluster 25, #34 Elements
# 	 afm images also affected nonlinearity hysteresis ref creep piezoelectric material cross talk x z axes may require software enhancement filtering
# 	 lexical categories hard define khmer ref
# 	 ibm a dot matrix printer rated lpm
#
# Cluster 26, #34 Elements
# 	 capacitive detection metal coated cantilevers form capacitor another contact located behind cantilever ref
# 	 the afm signals sample height cantilever deflection recorded computer x scan
# 	 scanners characterized sensitivity ratio piezo movement piezo voltage e much piezo material extends contracts per applied volt
#
# Cluster 27, #33 Elements
# 	 cumberland farms large convenience store chain takes name original dairy farm business cumberland rhode island
# 	 a couple months later gardiners take elizabeth trip peak district visit also includes darcy estate pemberley elizabeth agrees go believing away travelling
# 	 after jacobson forced business cummings developed drug connections based bahamas
#
# Cluster 28, #32 Elements
# 	 lorde actively strived change culture within feminist community implementing womanist ideology
# 	 adjectives demonstratives numerals follow noun modify
# 	 however spoken discourse osv possible emphasizing object topic comment like structure ref
#
# Cluster 29, #31 Elements
# 	 phnom penh khmer spoken capital surrounding areas
# 	 mid february the th armada makes stop mozambique island repair supply
# 	 autism awareness campaign uk the autism awareness campaign uk involved first united nations world autism awareness day declared un general assembly wednesday april recommendation state qatar
#
# Cluster 30, #31 Elements
# 	 in many countries customer pay small deposit inserting coin token card returned customer returns cart designated cart parking point
# 	 in australia deposit systems common local government areas made compulsory local law
# 	 statutes judicial rulings may create implied contractual terms particularly standardized relationships employment shipping contracts
#
# Cluster 31, #29 Elements
# 	 linda hunt born academy award winning actress ref
# 	 chris holmes swimmer he multiple paralympic gold medals swimming ref
# 	 while odu donovan helped lady monarchs win aiaw national title second straight record
#
# Cluster 32, #29 Elements
# 	 at beginning th century indiana gas boom gradually came end ref
# 	 among groups listed table german immigrants arrived quite early brazil starting
# 	 set forth law acquire brazilian nationality requirement persons originating portuguese speaking countries residence one uninterrupted year good moral repute
#
# Cluster 33, #28 Elements
# 	 mollie manufacturing facility tile mill ref
# 	 wagon new york hawaii
# 	 he member mental health taskforce ref chaired paul farmer led five year forward view psychiatry
#
# Cluster 34, #28 Elements
# 	 optical interferometry optical interferometry used measure cantilever deflection ref
# 	 image formation plotting method produces color mapping changing x position tip scanning recording measured variable e intensity control signal x coordinate
# 	 on hand df may kept constant moving probe upward downward see fig z direction using negative feedback using z feedback loop raster scan sample surface along x direction
#
# Cluster 35, #27 Elements
# 	 sarney government fulfilled tancredo promise passing constitutional amendment constitution inherited military regime summon elections national constituent assembly full powers draft enact new democratic constitution country
# 	 part ii article states the house representatives shall grand inquest state impeachments made shall heard tried senate
# 	 the committee conducted investigation proposed house adopt hr a resolution recommending impeachment supreme court chief justice david a brock authored
#
# Cluster 36, #26 Elements
# 	 dan olmsted investigative reporter former senior editor united press international upi news agency unification church company news world communications
# 	 colonel peter edmond late royal army medical corps territorial army
# 	 lilian louise lowne assistant secretary department industry
#
# Cluster 37, #26 Elements
# 	 in overseas sector the main leakage sector imports m represent spending residents rest world
# 	 despite success volumes release coal established lorde influential voice black arts movement norton well introducing wider audience
# 	 a company called amalgamated software north america asna produced third party compiler system late called rpg
#
# Cluster 38, #26 Elements
# 	 cummings began long career television starring comedy my hero ran episodes
# 	 autism limited focus interest activity preoccupation single television program toy game
# 	 a bbc news correspondent said news crew vehicle came attack youths throwing missiles ref
#
# Cluster 39, #25 Elements
# 	 william george assistant secretary department commerce central provincial government
# 	 edward norman eden under secretary department trade
# 	 acting lieutenant colonel cecil richardson combined cadet force territorial army
#
# Cluster 40, #25 Elements
# 	 future northern indiana including became harrison township mollie flattened two glaciers millions years ago ref
# 	 one principal diplomatic problems th century europe called eastern question concerned declining ottoman empire
# 	 when brazil invaded new land new world portuguese native population composed million amerindians ref whose ancestors living last years ref
#
# Cluster 41, #25 Elements
# 	 recently moeller unveiled plans build multipurpose stadium campus named gerry faust athletic complex foot bronze statue honoring entrance however plan faced strong criticism neighboring homeowners moeller request change zoning regulation denied
# 	 in united states children injured year shopping carts ref
# 	 the special edition dvd film released march festival media ref
#
# Cluster 42, #24 Elements
# 	 the squire student literary journal features stories poems essays written moeller students
# 	 her writings based theory difference idea binary opposition men women overly simplistic although feminists found necessary present illusion solid unified whole category women full subdivisions ref
# 	 audre lorde criticism feminists identified issues race class age gender sexuality
#
# Cluster 43, #24 Elements
# 	 this device commonly called afm probe names include afm tip cantilever employing name single part name whole device
# 	 the phonological system described inventory sounds standard spoken language ref represented using appropriate symbols international phonetic alphabet ipa
# 	 counting khmer based biquinary system numbers form five one five two etc
#
# Cluster 44, #24 Elements
# 	 other intonation contours signify different type phrase full doubt interrogative similar yes questions english
# 	 a complete khmer sentence consists four basic elements include optional topic optional subject obligatory predicate various adverbials particles ref
# 	 consideration concept devised english common law required simple contracts special contracts contracts deed
#
# Cluster 45, #23 Elements
# 	 a machine shop cumberland made first power looms woolens america ref
# 	 after meeting first wife moved san francisco would live california rest life
# 	 in cummings announced would form production company laurel named daughter street lived laurel way
#
# Cluster 46, #23 Elements
# 	 there games library called funlib contained games like star trek football hangman coffee grand prix biorhythm program
# 	 the film televised august cbc news network program the passionate eye ref
# 	 music gangs wasseypur launched may
#
# Cluster 47, #22 Elements
# 	 in the crusader first place second highest honor high school newspaper receive american scholastic press association ref
# 	 as child lorde struggled communication came appreciate power poetry form expression ref
# 	 after scoring first rank maharashtra public service commission mpsc examination year also succeeded union public service commission upsc examination selected much coveted indian foreign service
#
# Cluster 48, #22 Elements
# 	 in spent pivotal year student national university mexico period described time affirmation renewal
# 	 due change definition clinical pathways care year largely uninformative current era ref
# 	 undue influence equitable doctrine involves one person taking advantage position power another person special relationship parent child solicitor client
#
# Cluster 49, #22 Elements
# 	 the relative popularity beam deflection method explained high sensitivity simple operation fact cantilevers require electrical contacts special treatments therefore fabricated relatively cheaply sharp integrated tips
# 	 laser doppler vibrometry a laser doppler vibrometer used produce accurate deflection measurements oscillating cantilever ref thus used non contact mode
# 	 operation mode image forming afm generally classified two groups viewpoint whether uses z feedback loop shown maintain tip sample distance keep signal intensity exported detector
#
# Cluster 50, #21 Elements
# 	 exclamatory phrases follow typical steadily rising pattern rise sharply last syllable instead falling ref
# 	 after breach occurred innocent party duty mitigate loss taking reasonable steps
# 	 contract theory body legal theory addresses normative conceptual questions contract law
#
# Cluster 51, #20 Elements
# 	 s t m i g x
# 	 s t m i g x
# 	 kit p d del exon a subset gastrointestinal stromal tumors previously regarded wild type tumors carries somatic activating mutations kit exon p d del ref
#
# Cluster 52, #20 Elements
# 	 lorde set confront issues racism feminist thought
# 	 lorde defines racism sexism ageism heterosexism elitism classism altogether explains ism idea privileged superior right govern anything else
# 	 jonaki collection poetry marathi passionate poems young sensitive mind trying figure hidden meanings social political cultural economic happenings times
#
# Cluster 53, #20 Elements
# 	 professional country music session musicians typically use music notated nashville number system indicates chord progression using numbers enables bandleaders change key moment notice
# 	 television director joe wright hired early making pride prejudice directional feature film debut
# 	 wright found casting film difficult particular types people wanted work
#
# Cluster 54, #19 Elements
# 	 by late butuan industry specialized timber earning nickname timber city south
# 	 an aborted attempt trip around world friend piqued interest american southwest began tour kansas colorado new mexico moving eastern foothills rocky mountains
# 	 the temporary motor racing circuit streets city hosts pau grand prix
#
# Cluster 55, #18 Elements
# 	 the key success lha regular review brma across england rent officer extensive development lettings information held the rent service
# 	 a similar process occurred santa catarina initially two main destinations german immigrants blumenau created joinville immigrants descendants moved areas
# 	 the cloister garden courtyard surrounded domestic buildings abbey mostly constructed late th century
#
# Cluster 56, #18 Elements
# 	 in bessie decamp invented seat belt chairs go carts carriages ref
# 	 thor arrives tells loki silent threatens rip loki head body hammer
# 	 february the th armada arrives malindi
#
# Cluster 57, #18 Elements
# 	 tales thor influenced native traditions regarding thor continued modern period particularly scandinavia
# 	 in ancient greek music three hymns mesomedes crete exist manuscript
# 	 before th century western music written hand preserved manuscripts usually bound large volumes
#
# Cluster 58, #18 Elements
# 	 a lead sheet specifies melody lyrics harmony using one staff chord symbols placed lyrics
# 	 a fake book collection jazz songs tunes basic elements music provided
# 	 a tablature special type musical score typically solo instrument shows play pitches given instrument rather pitches produce rhythm indicated well
#
# Cluster 59, #17 Elements
# 	 lorde poetry became open personal grew older became confident sexuality
# 	 prohibitives take form v also often softened addition particle end phrase ref
# 	 as result gods goddesses meet hold thing discuss debate matter
#
# Cluster 60, #17 Elements
# 	 the model positioned replacement announced october ref
# 	 ssp system support program operating system s
# 	 in fujitsu introduced world first inch cm full color display
#
# Cluster 61, #17 Elements
# 	 the terms marriage settled two agreements public treaty private contractual arrangement
# 	 compensatory damages given party detrimented breach contract
# 	 recently accepted third category restitutionary obligations based unjust enrichment defendant plaintiff expense
#
# Cluster 62, #16 Elements
# 	 the raid cranganore defection tanur serious setbacks zamorin pushing frontline north effectively placing vembanad lagoon zamorin reach
# 	 manuel casanova
# 	 the ufe sife world champion
#
# Cluster 63, #16 Elements
# 	 despite official bbc report stating letitia dean taking scheduled break would return eastenders later happen away show six years
# 	 the mortgage specialists inc v implode explode heavy industries inc n h the court found internet news outlets treated traditional print media receive legal privileges granted journalists
# 	 less common unilateral contracts one party makes promise side promise anything
#
# Cluster 64, #16 Elements
# 	 user id password menu optional
# 	 screen formats generated object code
# 	 passing four digit code assembler routine returned associated text
#
# Cluster 65, #15 Elements
# 	 other businesses mollie included general store cider mill blacksmith shop
# 	 near end world war i army biplane forced land near mollie engine failure
# 	 sardar becomes feared man wasseypur shifts business stealing iron ore
#
# Cluster 66, #15 Elements
# 	 want go siem reap ref
# 	 the revolution cup work great impact muslims countries
# 	 by end th century entire economy came resemble often referred banana republic economy one controlled foreign interests small domestic elite oriented toward production single agriculture export
#
# Cluster 67, #15 Elements
# 	 the return sharon six years later became seminal moment show ref eclipsed intense media scrutiny surrounding den return two years later ref
# 	 the game direct contrast quarter final hungary brazil hungary uruguay played attractive attacking football arguably one finest displays football world cup
# 	 in march man also called disturbing events kwajalein johnston atoll weapon targeted certain people could leave others unhurt
#
# Cluster 68, #15 Elements
# 	 england anxious revenge defeat wembley return match scheduled budapest may three weeks start world cup
# 	 on october named sun belt conference all time women basketball player
# 	 donovan took head coaching duties usa national team far change team
#
# Cluster 69, #15 Elements
# 	 a low tech form theft prevention utilizes physical impediment vertical posts store entrance keep carts taken parking lot
# 	 owing overwhelming success many different manufacturers desired produce shopping carts rear swinging door feature denied due exclusive license issued goldman
# 	 its conclusion published march rent regulation working well
#
# Cluster 70, #14 Elements
# 	 on october senior associate justice nadeau hand delivered resignation letter governor john lynch announcing retirement court effective december governor council accepted
# 	 morristown located th congressional district ref part new jersey th state legislative district ref
# 	 a caller named daniel murray claimed majestic agent downey california
#
# Cluster 71, #14 Elements
# 	 although den first second wives appeared screen combined total years angie chrissie immense impact show watts family
# 	 details explained case especially constant df mode fm afm among afm instance next section
# 	 scores baroque period often form bass line bass clef melodies played instrument sung upper stave staves treble clef
#
# Cluster 72, #14 Elements
# 	 the primary purpose csp keep msp busy ran slightly x speed msp
# 	 early paley started drawing new three panel comic strip called mimi eunice
# 	 in warren went bankrupt recently dark horse comics reprinting warren old stories revived creepy eerie magazines
#
# Cluster 73, #14 Elements
# 	 it relationship den princess central dynamic watts family
# 	 it noted despite nomenclature repulsive contact occur avoided amplitude modulation afm frequency modulation afm depending settings
# 	 when gist suspected opposed causes similar tumors pathologist use immunohistochemistry specific antibodies stain molecule cd also known c kit see
#
# Cluster 74, #14 Elements
# 	 the act apply houses erected course erection april date later reconstructed two separate self contained flats tenements
# 	 they reported gradual decontrol inaugurated act worked satisfactorily regard medium sized houses slowly largest quickly smallest
# 	 in conjunction continuous improvement fischer tropsch process catalyst significant developments also made mining technology
#
# Cluster 75, #14 Elements
# 	 gist introduced diagnostic term ref
# 	 if cd stain negative suspicion remains tumor gist newer antibody dog discovered on gist used
# 	 wrong planet sometimes referred url wrongplanet
#
# Cluster 76, #14 Elements
# 	 the title went second team ohio high school boys volleyball history go undefeated
# 	 hungary continued dominate international football july february hungary played games winning drawing losing none
# 	 the new jersey minutemen professional inline hockey team competes eastern conference professional inline hockey association
#
# Cluster 77, #13 Elements
# 	 musica viva coffee concerts held sydney melbourne five tuesday mornings throughout year
# 	 wealthy bachelor charles bingley recently moved netherfield large nearby estate
# 	 terence vaughan forrest australian capital territory
#
# Cluster 78, #13 Elements
# 	 anurag kashyap said wanted make film bihar name bihar time various reasons take
# 	 butuan city known education competence
# 	 enver pasha minister war easily charismatic three ruled war hero one popular public
#
# Cluster 79, #13 Elements
# 	 this say circular flow diagram useful understanding basics economy leakages injections
# 	 in marxian economics economic reproduction refers recurrent cyclical processes ref initial conditions necessary economic activity occur constantly created ref
# 	 rather two mrs watts highly individual volatile figures dominated relationship den
#
# Cluster 80, #13 Elements
# 	 september the th armada appears calicut
# 	 the beginning saw introduction japanese anime series american culture
# 	 cummings formed company united california productions
#
# Cluster 81, #13 Elements
# 	 preferred imaging modalities evaluation gists ct mri ref selected situations endoscopic ultrasound
# 	 in review aggregator website reviewgang movie received stars based reviews ref
# 	 improvements security tenure available occupants agricultural tied cottages made agriculture act
#
# Cluster 82, #13 Elements
# 	 the model called system pc desktop also informally baby name later attached software program produced california software products inc
# 	 windows uses point click ssp important function enter rec adv also known enter
# 	 cnfigssp used place devices line address map identify particular ibm printer terminal model assign characteristics console alternate console subconsole name printer subconsole
#
# Cluster 83, #13 Elements
# 	 an afm probe sharp tip free swinging end cantilever protruding holder ref
# 	 another scene movie muslim girl kidnapped singh men portrayed conversely
# 	 the swastika symbol identified representing hammer lightning thor ref
#
# Cluster 84, #13 Elements
# 	 political liberalization declining world economy contributed brazil economic social problems
# 	 however european union united states need prevent discrimination eroded full extent freedom contract
# 	 right beginning war unionist leadership envisioned war total war resources entire society engaged war proved
#
# Cluster 85, #13 Elements
# 	 the loss support resulting scandals outweighed president popularity among voters lower classes whose income per capita raised consequence higher employment expansion domestic credit consumers government social welfare programs
# 	 the third interest controlling nation production somoza family wide holdings almost every segment nicaraguan society
# 	 between bolivian immigrants come brazil every month looking job
#
# Cluster 86, #13 Elements
# 	 nd strongest power rating ever attained sport history using elo rating system national teams points june
# 	 in season donovan became first female coach win games storm made playoffs lost first round
# 	 the men singles final briefly interrupted jimmy jump carrying fc barcelona banner ran onto court second set running around roger federer even putting cap jumping net taken security
#
# Cluster 87, #13 Elements
# 	 first regulation impedes flow income throughout social classes therefore economic development
# 	 a major critique womanism failure explicitly address homosexuality within female community
# 	 another dimension theoretical debate contract place within relationship wider law obligations
#
# Cluster 88, #12 Elements
# 	 the honourable oscar tammur for services politics government
# 	 professor ronald mason chief scientific adviser ministry defence
# 	 john murray hunter commissioner for administration finance forestry commission
#
# Cluster 89, #12 Elements
# 	 his abilities allowed build alliance pmdb defectors pds founded liberal front party pfl
# 	 equally important given large number army officers unionists influence goltz trained entire generation ottoman officers called goltz generation
# 	 an extensive purge army carried january officers including field marshals generals lieutenant generals major generals colonels enver considered inept disloyal forced take early retirement
#
# Cluster 90, #12 Elements
# 	 the whippany line morristown erie railway small freight line traverses township
# 	 the capital canton aarau located western border aare
# 	 patan railway station km ahmedabad railway station
#
# Cluster 91, #12 Elements
# 	 khmer spoken million people cambodia official language
# 	 a khmer syllable begins single consonant else cluster two rarely three consonants
# 	 stress khmer falls final syllable word ref
#
# Cluster 92, #12 Elements
# 	 bern used aargau bailiwicks mostly source grain rest city state
# 	 the f minine de pau walking race held twice per year
# 	 the area land antoine de la calmette bought partly marshy partly wooded
#
# Cluster 93, #12 Elements
# 	 in addition diphthongs triphthongs analyzed vowel nucleus plus semivowel coda followed final consonant
# 	 slight vowel epenthesis occurs clusters consisting plosive followed beginning cluster ref
# 	 pronouns subject complicated system social register choice pronoun depending perceived relationships speaker audience referent see social registers
#
# Cluster 94, #12 Elements
# 	 piezoelectric detection cantilevers made quartz ref qplus configuration piezoelectric materials directly detect deflection electrical signal
# 	 the afm consists cantilever sharp tip probe end used scan specimen surface
# 	 the detector afm measures deflection displacement respect equilibrium position cantilever converts electrical signal
#
# Cluster 95, #12 Elements
# 	 some retailers target begun using carts fully made recycled plastic metal part wheel axles drawing away established metal cart design
# 	 in airports system similar shopping cart deposit also used luggage carts profit making opportunity
# 	 most retailers north america utilize cart retrieval service collects carts found store premises returns store fee
#
# Cluster 96, #12 Elements
# 	 the court hears variety cases either mandatory discretionary appeals lower courts
# 	 in december supreme court instituted three judges expedited jx summary procedure reduce cases requiring oral argument
# 	 justices assigned sit temporarily supreme court authority supreme court justice hear arguments render decisions file opinions
#
# Cluster 97, #11 Elements
# 	 frank henry corner wellington
# 	 flight sergeant gary david bydder a
# 	 captain robert kenneth alcock
#
# Cluster 98, #11 Elements
# 	 he moved greenwich village attended the new school dropping live postulant holy cross monastery west park new york
# 	 st peter episcopal church large mckim mead white church bell tower fine stained glass medieval furnishings
# 	 enfield town centre enfield town park alleyways palace garden shopping centre guarded police
#
# Cluster 99, #11 Elements
# 	 one works sister outsider the master tools will never dismantle master house
# 	 returning home halifax family mukpo reflects upon life upon experiences tulkus teachers interviewed
# 	 sheet music issued individual pieces works example popular song beethoven sonata collections example works one several composers pieces performed given artist etc
#
# Cluster 100, #11 Elements
# 	 applications field solid state physics include identification atoms surface b evaluation interactions specific atom neighboring atoms c study changes physical properties arising changes atomic arrangement atomic manipulation
# 	 wessely main research interests lie grey areas medicine psychiatry clinical epidemiology military health
# 	 with extraction chemicals fischer tropsch product slate coupled downstream functionalization purpose chemical production facilities sasol moved south african fuels company become international integrated energy chemicals company chemical products sold worldwide
#
# Cluster 101, #11 Elements
# 	 although sheet music often thought platform new music aid composition e composer writes music also serve visual record music already exists
# 	 rexroth wrote large body literary cultural criticism much compiled anthologies
# 	 much rexroth work classified erotic love poetry given deep fascination transcendent love
#
# Cluster 102, #11 Elements
# 	 the musician in the classroom residency program sends professional musicians composers work directly students
# 	 when separate instrumental vocal parts musical work printed together resulting sheet music called score
# 	 a collection songs given musical usually printed label vocal selections
#
# Cluster 103, #11 Elements
# 	 malignancy characterized local invasion metastases usually liver omentum peritoneum
# 	 if resistance imatinib encountered multiple tyrosine kinase inhibitor sunitinib marketed sutent considered ref ref
# 	 the effectiveness imatinib sunitinib depend genotype ref
#
# Cluster 104, #11 Elements
# 	 a system use cattle grid style system
# 	 disk space system organized blocks
# 	 it provided password security resource security allowing control allowed access program file
#
# Cluster 105, #11 Elements
# 	 some agricultural workers forestry workers members families enjoyed security occupation rent acts
# 	 of working population used public transportation get work used private car ref
# 	 commercial fishing vessels used exploit association searching dolphin pods
#
# Cluster 106, #10 Elements
# 	 state v aubert n h court reversed conviction used alternate reasonable doubt instruction court indicated trial judges depart wentworth instruction
# 	 sweezy v new hampshire citing due process clause fourteenth amendment u s supreme court reversed affirmation contempt finding subversive person refused answer questions activities attorney general subsequently refused state superior court
# 	 dfu programs generated subroutine r code wsu programs
#
# Cluster 107, #10 Elements
# 	 early january after brief stop cannanore lopo soares th armada set sail back across indian ocean
# 	 autism false prophets written vaccine expert paul offit
# 	 in episode history doom revealed giganta normal woman horseriding witnessed apache chief using magic dust
#
# Cluster 108, #10 Elements
# 	 on children segment kahlil gibran the prophet
# 	 alexithymia term coined psychotherapist peter sifneos describe state deficiency understanding processing describing emotions
# 	 when horacio returns argentina greeted old friend manolo nicknamed traveler wife talita
#
# Cluster 109, #10 Elements
# 	 in king spain made official state visit united kingdom
# 	 the spanish royal family went exile april municipal elections brought republicans power major cities leading proclamation second spanish republic
# 	 by bnei menashe moved israel settled west bank gaza strip disengagement
#
# Cluster 110, #10 Elements
# 	 the first visualize modern circular flow income model frank knight publication the economic organization ref
# 	 according united states census bureau town total area land water ref
# 	 in addition minnesota became first state ban discrimination based gender identity sexual orientation based human rights act ref
#
# Cluster 111, #10 Elements
# 	 his vice president itamar franco assumed presidency remainder collor term
# 	 chadda revealed interview role helped bag film roles ref
# 	 on contrary raja sen rediff gave movie stars concluding it excess suffocates magic originality dying lack room breathe
#
# Cluster 112, #10 Elements
# 	 operation withern launched investigate cause mark duggan fatal shooting subsequent riots ref
# 	 the victims children filed civil lawsuit may vancouver police department royal canadian mounted police crown failing protect victims ref
# 	 when committee non violent action sponsored protest august camp mercury nuclear test site near las vegas nevada protesters attempted enter test site knowing faced arrest
#
# Cluster 113, #10 Elements
# 	 contributed articles hindi daily dainik bhaskar
# 	 portions writing included text books karnataka japan
# 	 more generally writers propounded marxist feminist interpretations contract
#
# Cluster 114, #10 Elements
# 	 the pasiegan jump another outstanding rural sports region clear example use work skill disappears pass time gives rise games competition
# 	 solo featured along national teammates ea sports fifa video game series starting fifa first time women players included game ref
# 	 on june announced solo would starting goalkeeper u s team summer olympics beijing
#
# Cluster 115, #10 Elements
# 	 the equation economic equilibrium disequilibrium s t m i g x five sector model levels income expenditure output greatly rise causing boom economic activity
# 	 in october presidential elections fernando henrique cardoso elected votes
# 	 following report onslow committee rent mortgage interest restrictions act became first measure reverse machinery control
#
# Cluster 116, #10 Elements
# 	 various authors proposed slightly different analyses khmer vowel system
# 	 the brazilian censuses ask questions ethnic origin systematically comparable data impact immigration
# 	 the embassy figures arab brazilians imply impossible rate childbirth
#
# Cluster 117, #10 Elements
# 	 to attack soaring debt figueiredo administration stressed exports food natural resources automobiles arms clothing shoes even electricity expanded petroleum exploration foreign companies
# 	 during british colonial rule british seized farm lands dhanbad coal began business coal mining dhanbad
# 	 from bitterly cold continent glacia thinkquick uses tugboat jet nozzle shift gulf stream warm homeland weather disrupted around globe
#
# Cluster 118, #10 Elements
# 	 many contracts contain clause setting disputes relation contract litigated
# 	 the law applicable contract dependent conflict laws legislation court action relation contract brought
# 	 to recover damages claimant must show breach contract caused foreseeable loss ref
#
# Cluster 119, #10 Elements
# 	 despite initial decrease inflation returned higher economic plans achieving month
# 	 as military position central powers disintegrated october government resigned
# 	 economic growth continued largely result industrialization
#
# Cluster 120, #10 Elements
# 	 special order gb january december
# 	 special order gb october september
# 	 special order gb october october
#
# Cluster 121, #9 Elements
# 	 the loss rumelia reduced need ottomanism defeat first balkan war seemingly showed empire christian population always disloyal thus allowing public display turkish nationalism
# 	 rexroth pacifist conscientious objector world war ii ref actively involved helping japanese americans forcibly sent internment camps war
# 	 hungary opening game south korea kocsis scoring hat trick
#
# Cluster 122, #9 Elements
# 	 regorafenib stivarga fda approved advanced gists cannot surgically removed longer respond imatinib gleevec sunitinib sutent ref
# 	 a high temperature syngas conversion process operated secunda series sasol advanced synthol sastm reactors high pressure aid iron based fischer tropsch catalyst c yield primarily c c range hydrocarbons
# 	 the cartridge operated extinguisher invented read campbell england used water water based solutions
#
# Cluster 123, #9 Elements
# 	 in natural gas discovered nearby hartford city blackford county began participation indiana gas boom ref
# 	 in summer ref cumberland american little league baseball team led coach david belisle new england regional little league baseball championship went play little league world series
# 	 after spending offseason hunting smoky joe wood ref coveleski returned indians throughout season indians battled yankees first american league
#
# Cluster 124, #9 Elements
# 	 in essay the erotic power written collected sister outsider lorde theorizes erotic site power women learn release suppression embrace
# 	 lorde work black feminism continues examined scholars today
# 	 her second volume cables rage mainly written tenure poet residence tougaloo college mississippi addressed themes love betrayal childbirth complexities raising children
#
# Cluster 125, #9 Elements
# 	 although almost ubiquitous continental europe deposit system less common united kingdom canada widely adopted united states exception chains like aldi require deposit
# 	 in january enver decided save empire anatolia would become ethnically turkish
# 	 the chinese revolution russian revolution diverted attention world revolutionaries young turk revolution
#
# Cluster 126, #9 Elements
# 	 stm the first atomic microscope used stm complete feedback mechanism measure deflection ref
# 	 afm several advantages scanning electron microscope sem
# 	 force spectroscopy used biophysics measure mechanical properties ref living material tissue cells ref
#
# Cluster 127, #9 Elements
# 	 a survey roughly trans women showed identified heterosexual bisexual lesbian asexual queer ref
# 	 some feminists argue medicalization asexuality ref
# 	 a bisexual woman filed lawsuit lesbian feminist magazine common lives lesbian lives alleging discrimination bisexuals submission published ref
#
# Cluster 128, #9 Elements
# 	 edwin moses gold medal hurdles years winning
# 	 france olympic soccer tournament defeating brazil final
# 	 the quarterfinal match u s brazil sent penalty shoot u s forward abby wambach tied game stoppage time end extra time
#
# Cluster 129, #9 Elements
# 	 heisting raw plastic powder king plasto creates frerp
# 	 cr pes made pouring wheat batter onto frying pan flat circular hot plate often trace butter vegetable oil pan surface
# 	 common savoury fillings cr pes served lunch dinner cheese ham eggs ratatouille mushrooms artichoke certain regions various meat products
#
# Cluster 130, #9 Elements
# 	 employing white dwarf star technology menagerie man sports shrunken zoo trained animals produce seemingly thin air
# 	 high flying super villain capable emitting powerful sparks hands teamed riddler
# 	 by growing trend towards grim gritty anti heroes increasing violence comics
#
# Cluster 131, #9 Elements
# 	 the first direct presidential election years held october first round november second round
# 	 parliamentary elections held october government failed win reliable base congress president started lose support
# 	 the process transition towards democracy culminated end military regime adoption new democratic constitution however troubled
#
# Cluster 132, #9 Elements
# 	 the advisory committee judicial ethics provides advisory opinions appropriate rules court statutes relating ethical professional conduct judges advise would evidence good faith disciplined
# 	 in contrast domestic social agreements children parents typically unenforceable basis public policy
# 	 high functioning autism informal term applied autistic people deemed higher functioning autistic people one metrics
#
# Cluster 133, #9 Elements
# 	 as august total arrested estimated damage recorded shops premises ref
# 	 excavations continued november cost investigation estimated million end according provincial government ref
# 	 the communal population pau amounts inhabitants according census legal populations january
#
# Cluster 134, #9 Elements
# 	 the afm applied problems wide range disciplines natural sciences including solid state physics semiconductor science technology molecular engineering polymer chemistry physics surface chemistry molecular biology cell biology medicine
# 	 hyperbaric oxygen therapy medical use oxygen level higher atmospheric pressure
# 	 sedimentary rocks preserve remnants history life earth form fossils biomarkers isotopes traces
#
# Cluster 135, #9 Elements
# 	 following educational reform swedish finnish became compulsory school subjects
# 	 the school regular fixture list major uk public schools
# 	 an exchange programme set saw lower sixth boy study mayo lower sixth boy mayo study teddy
#
# Cluster 136, #9 Elements
# 	 in real flow household sector supplies raw material land labour capital enterprise firms return firms sector provides finished goods services household sector
# 	 the somoza family owned estimated country arable land heavily involved food processing industry controlled import export licenses
# 	 unlike traditional cattle raising subsistence farming coffee production required significant capital large pools labor
#
# Cluster 137, #8 Elements
# 	 again family increasingly dominated volatile relationship husband wife culminating den death february leslie grantham decided extend current contract
# 	 from death new york state poet laureate ref
# 	 count cynthia feliks ref last seen december
#
# Cluster 138, #8 Elements
# 	 during war italy central committee established called special organisation conduct guerrilla operations italians libya
# 	 it include germans immigrated russian passports see volga germans
# 	 in islamic futures sardar enunciates several principles need heart contemporary islamic societies
#
# Cluster 139, #8 Elements
# 	 gangs wasseypur collected cr first four days
# 	 the oryx gtl plant qatar joint venture sasol qatar petroleum launched
# 	 it contains famous hot sulphur springs baden schinznach bad rheinfelden extensive saline springs
#
# Cluster 140, #8 Elements
# 	 the colony new hampshire adopted temporary constitution
# 	 lilleshall immediately dissolved like marginal houses surrendered king compulsorily suppressed october ref
# 	 the building operated zil throughout history known likhachev palace culture
#
# Cluster 141, #8 Elements
# 	 the rent officer service established the rent service executive agency department environment transport regions october
# 	 the energy business manages marketing sales oil gas electricity products southern africa consolidated single umbrella
# 	 administrators managers directors hired commercial enterprise civil organization resulting foreign investment described item work contract pre approved brazilian ministry labor national department employment
#
# Cluster 142, #8 Elements
# 	 cardoso put together successful stabilization program plano real brought inflation annually
# 	 the principles aerodynamic lift shared nature man made aircraft
# 	 some explain power shabbat effect six days week role moving society towards messianic age
#
# Cluster 143, #8 Elements
# ...
# 	 a second replica matthew located cape bonavista
# 	 the monument originally consisted sarsen stone chamber covered low earthen mound bounded prostrate slabs
#
# Cluster 240, #5 Elements
# 	 in october bell interviewed temple vampire representative nemo
# 	 the rugby stadium historic seat section paloise youth teams play today
# 	 when sixth form fully co educational girls members boys houses slept oakthorpe
#
# Cluster 241, #5 Elements
# 	 legal international availability anime internet changed recent years simulcasts series available websites like crunchyroll
# 	 in wally wood hit upon idea publishing comic selling comic book specialty shops
# 	 public void testsumzeroneutral adder adder new adderimpl assert adder add
#
# Cluster 242, #5 Elements
# 	 after births children victoria eugenie relationship alfonso deteriorated numerous affairs
# 	 eventually sardar returns home nagma gets pregnant
# 	 in fisher married young woman engaged another
#
# Cluster 243, #5 Elements
# 	 an assassin specializing eliminating world leaders kingslayer hired overlord kill global rulers bid seize power
# 	 in dark night small groups darkly clad jews led treacherous paths liselund park beach boarded small boats would take sweden
# 	 after pequot war colonial government declared dominant pequot tribe extinct even though survivors descendants continued remain former territory
#
# Cluster 244, #5 Elements
# 	 the chaotic legal structure fragmented land ownership combined tradition dividing land among heirs inheritance prevented large scale reforms
# 	 thoreau essay civil disobedience originally titled resistance civil government wide influence many later practitioners civil disobedience
# 	 one theory disobedience may helpful great amount would undermine law encouraging general disobedience neither conscientious social benefit
#
# Cluster 245, #5 Elements
# 	 on august ottoman german governments signed secret offensive defensive alliance
# 	 the swedish nationality movement effectively mobilized aftermath finnish independence civil war shortly followed
# 	 in post famine era dejection led mass emigration
#
# Cluster 246, #5 Elements
# 	 y e o this means expenditure buyers households becomes income sellers firms
# 	 s t m i g x levels income expenditure output fall causing contraction recession overall economic activity
# 	 institut de promotion commerciale ipc
#
# Cluster 247, #5 Elements
# 	 imatinib approved metastatic unresectable gist us fda february
# 	 coveleski status ace staff demonstrated named starter opening day season
# 	 dexter laboratory first appeared home media three vhs tapes made widely available early
#
# Cluster 248, #5 Elements
# 	 in spare time sinatra enjoyed listening classical music would attend concerts could
# 	 the skill sight reading ability musician perform unfamiliar work music upon viewing sheet music first time
# 	 blind boy fuller blues guitarist vocalist ref
#
# Cluster 249, #5 Elements
# 	 on november bell left dark matter six weeks ref
# 	 in bell appeared series millennium
# 	 in bell featured video game prey played
#
# Cluster 250, #5 Elements
# 	 her conception many layers selfhood replicated multi genres work
# 	 womanism existence naturally opens various definitions interpretations
# 	 nokarshahiche rang a autobiographical book life experiences various places countries
#
# Cluster 251, #5 Elements
# 	 mollie located intersection county roads north east
# 	 the north spanish state rich area mythology
# 	 stockton located along delaware river north lambertville
#
# Cluster 252, #5 Elements
# 	 on september bell took call frantic man claiming ex area employee grew progressively upset call wore culminating show going temporarily air satellite failure
# 	 bell generally chooses discuss political views coast coast am though occasionally brought
# 	 on february google street view extended coverage canada including streets within rouleau
#
# Cluster 253, #5 Elements
# 	 vii complaint indictment brazil abroad felony threatened minimum sentence imprisonment abstractly considered one year
# 	 pickton also stood accused first degree murder deaths twenty women charges stayed august
# 	 having regards age character antecedents offender circumstances offence committed court convicting accused considers expedient release offender may either probation good conduct due admonishment
#
# Cluster 254, #5 Elements
# 	 frank setterich chief officer assistant crown agents for oversea governments administrations
# 	 bcs governed trustee board comprising president deputy president immediate past president nine vice presidents including vice president finance five professional members elected advisory council ref
# 	 aarhus municipality electoral wards polling stations four electoral districts folketing national parliament ref
#
# Cluster 255, #5 Elements
# 	 in economy floundered gdp declined impact accelerated rising inflation failure political leadership
# 	 by mid government economic dictatorial political policies alienated nearly sectors society
# 	 a series political problems natural disasters continued plague economy
#
# Cluster 256, #5 Elements
# 	 while foreigners received amnesty obtained right work access health education services unable vote run public office
# 	 permanent visas may granted individuals intending establish residence brazil
# 	 the term settled usually taken mean chinese national parent permanent residency another country
#
# Cluster 257, #5 Elements
# 	 through grants special funding musica viva also creates special music projects remote disadvantaged special needs schools students
# 	 as education hub butuan colleges variety courses
# 	 she taught design technology section parsons part the new school ref
#
# Cluster 258, #5 Elements
# 	 the fbi secret dossier sinatra released response freedom information act requests
# 	 on december us armed forces transferred facility afghan government
# 	 the george w bush administration avoided using label prisoner war discussing detainees held bagram preferring immediately classify unlawful enemy combatants
#
# Cluster 259, #5 Elements
# 	 in situation circumstances came new piece legislation major turning point
# 	 it took time nature problem finally accepted management search began new location
# 	 work continued known h s mk
#
# Cluster 260, #5 Elements
# 	 in th century music industry dominated sheet music publishers
# 	 the band continued play live looking another record deal
# 	 the band first album tender years became major hit album
#
# Cluster 261, #5 Elements
# 	 thirdly sebes encouraged players versatile ideal would players able play position
# 	 digital creator set engaging qualifications teach digital media skills creative projects
# 	 as forward richland high school solo scored goals leading team three consecutive league titles state championship senior year ref
#
# Cluster 262, #5 Elements
# 	 by middle th century morristown residents two churches courthouse two taverns two schools several stores numerous mills farms nearby
# 	 from pau served network horse tramways
# 	 in butter markets operated wednesdays fridays near present creamery
#
# Cluster 263, #5 Elements
# 	 lorde focused discussion difference differences groups women conflicting differences within individual
# 	 there several difficulties translating new printing press technology music
# 	 an institution must unceasingly go front phase scientific technological progress based solely assets
#
# Cluster 264, #5 Elements
# 	 on november film debuted united states opening weekend million screens
# 	 the emergence world wide web cyberpunk genre spawned several internet themed films
# 	 the movie made broadcast premiere ctv december
#
# Cluster 265, #5 Elements
# 	 the lacrosse team two state titles constant force state midwest
# 	 with worldwide membership members countries bcs registered charity incorporated royal charter
# 	 when dawned club finally turned sixth quarterly magazine two issues year three years life
#
# Cluster 266, #5 Elements
# 	 the corner gas opening sequence follows cold open
# 	 the drawing smoke rooms located promenade deck
# 	 mcavoy park a park playing fields playground equipment
#
# Cluster 267, #5 Elements
# 	 i want look fish story
# 	 this something real true story i could tell way nobody else could
# 	 horacio life seems hopeless deemed failure
#
# Cluster 268, #5 Elements
# 	 compounds however preserve stress patterns constituent words
# 	 mental retardation mr generalized disorder appearing adulthood characterized significantly impaired cognitive functioning deficits two adaptive behaviors
# 	 global perceptions autism overview diagnosis treatment experience autism developing nations
#
# Cluster 269, #5 Elements
# 	 khmer dialects although mutually intelligible sometimes quite marked
# 	 most khmer words consist either one two syllables
# 	 complex sentences formed khmer addition one clauses main clause
#
# Cluster 270, #5 Elements
# 	 the champions going give without fight spent much remainder match launching attack attack hungarian defence
# 	 appearing much energy opponents hungary retook lead midway second period extra time s ndor kocsis headed home close range kocsis scored four minutes injury time
# 	 in second half hungary poured forward looking retake lead attempts repeatedly foiled german defence goalkeeper toni turek pulling several fine saves
#
# Cluster 271, #5 Elements
# 	 the turn millennium brought change school buildings facilities
# 	 fire extinguishers sometimes target vandalism schools open spaces
# 	 the building set back far possible give approach dignity provide essential parking space
#
# Cluster 272, #5 Elements
# 	 the red sox lost game even though early lead rbi single carl yastrzemski
# 	 by team found top heap led ruth another series championship chicago cubs
# 	 although montana appeared regular season games season threw passes ref
#
# Cluster 273, #5 Elements
# 	 the courts could suspend recent possession orders could suspend execution order possession twelve months could impose certain conditions terms
# 	 a preliminary inquiry held testimony covered publication ban
# 	 at time rumors surfaced former party chairman lien chen would run presidential election
#
# Cluster 274, #5 Elements
# 	 clomipramine trademarked anafranil tricyclic antidepressant tca
# 	 haloperidol typical antipsychotic
# 	 there two types cytocidal infections productive abortive
#
# Cluster 275, #5 Elements
# 	 in mollie population people community consisted two houses
# 	 from immigrants came brazil making annual average people
# 	 the majority population swedish finnish speakers farmers fishermen workers
#
# Cluster 276, #5 Elements
# 	 misrepresentation means false statement fact made one party another party effect inducing party contract
# 	 despite value critical prose dismissed works financially motivated
# 	 in opposed motion proposed will self psychiatrists blame current epidemic mental disorders
#
# Cluster 277, #5 Elements
# 	 class c fires involve flammable gases
# 	 class d fires involve combustible metals
# 	 antifreeze chemicals added water lower freezing point
#
# Cluster 278, #5 Elements
# 	 the surface cantilevers also modified
# 	 the rhode island state rock cumberlandite rare iron rich mineral unique region
# 	 the leveson never lived full time lilleshall numerous properties elsewhere
#
# Cluster 279, #5 Elements
# 	 early season coveleski pitched straight scoreless innings winning three consecutive games time ref
# 	 though san francisco finished record montana passed yards touchdown passes nine interceptions
# 	 montana excellent season earned second consecutive trip pro bowl
#
# Cluster 280, #5 Elements
# 	 the main school sports rugby hockey cricket rowing netball tennis squash athletics
# 	 the school many inter house sports events including steeplechase inter house hockey rugby netball squash swimming football among others
# 	 victor davis set new world record winning gold medal meter breaststroke swimming
#
# Cluster 281, #5 Elements
# 	 his knighthood services military healthcare psychological medicine ref
# 	 autism speaks world largest autism advocacy organization sponsors autism research conducts awareness outreach activities aimed families governments public
# 	 institute nursing training ifsi
#
# Cluster 282, #5 Elements
# 	 the guest rooms inside quite different chinese pompeian room
# 	 the methodist church built four mile water church hall village
# 	 seabreeze amusement park locally owned run amusement park one oldest nation
#
# Cluster 283, #5 Elements
# 	 starting freshman class moeller high school adopted new laptop program
# 	 big private universities like ateneo university de la salle university expressed put local branches
# 	 in addition public school system morristown several private schools
#
# Cluster 284, #5 Elements
# 	 an autobiographical novel expanded edition
# 	 the code also contained provisions suggestive salacious illustration required females drawn realistically without undue exposure
# 	 with pages agreement short paragraphs
#
# Cluster 285, #5 Elements
# 	 according census people brazil
# 	 dog river rouleau saskatchewan population according census sensibility
# 	 according united states census bureau borough total area square miles km including square miles km land square miles km water
#
# Cluster 286, #5 Elements
# 	 savings taxes imports investment government spending exports
# 	 economic changes included lifting import barriers exposing local companies international competition
# 	 one ma promises presidential candidate called plan promised economic growth rate unemployment rate less per capita income us
#
# Cluster 287, #5 Elements
# 	 conditions comorbid autism spectrum disorders these conditions people autism spectrum may suffer often typical
# 	 trans women like gender variant people face vast amount discrimination transphobia
# 	 when displaying identity documents incongruent gender identity expression harassed physically assaulted
#
# Cluster 288, #5 Elements
# 	 science fiction literature would continue influence early films
# 	 disaster film remained popular themes updated reflect recent influences
# 	 as every year one major science fiction fantasy films produced
#
# Cluster 289, #5 Elements
# 	 today faculty contains engineering specializations
# 	 bcs conducts bcs higher education qualifications many countries
# 	 the school provides regular programme school trips enhance curriculum
#
# Cluster 290, #5 Elements
# 	 chile second largest producer salmon world ref
# 	 summer spent lobster prawns crayfish
# 	 tuna important commercial fish
#
# Cluster 291, #5 Elements
# 	 the court made chief justice four associate justices
# 	 in general courts consolidated funding state courts state biennial budget
# 	 on february first regional assembly parliament formed provisional status
#
# Cluster 292, #5 Elements
# 	 as census people households families residing town
# 	 as march total registered voters morristown registered democrats registered republicans registered unaffiliated
# 	 as march total registered voters stockton registered democrats registered republicans registered unaffiliated
#
# Cluster 293, #5 Elements
# 	 an alternative shopping cart small hand held shopping basket
# 	 some retailers sell tokens alternative coins often charity
# 	 shopping cart theft costly problem stores use
#
# Cluster 294, #5 Elements
# 	 the return den years took conflict two families another level
# 	 for next five years fisher held number jobs
# 	 day saw start second round matches men women draws
#
# Cluster 295, #5 Elements
# 	 she attended hunter college high school secondary school intellectually gifted students graduated
# 	 there boarding houses home approximately boys girls
# 	 an application register female school made
#
# Cluster 296, #5 Elements
# 	 aspies for freedom aff solidarity campaigning group aims raising public awareness autism rights movement
# 	 autism network international founded run autistic people
# 	 autism sunday also known international day prayer autism asperger syndrome observed annually second sunday february
#
# Cluster 297, #5 Elements
# 	 there financial sector
# 	 there government sector
# 	 there foreign sector
#
# Cluster 298, #5 Elements
# 	 several types interaction detected
# 	 there three basic types questions khmer ref
# 	 there several different types damages

# %%
cluster_list2 = []
for i, cluster in enumerate(clusters2):
  cluster_list2.append(cluster)

# %%
sen2 = []
for i, cluster in enumerate(clusters2):
  for id in cluster[:]:
    sen2.append([i, training_data[id]])

# %%
df2=pd.DataFrame(sen2,columns=['cluster_no','sentences'])

# %%
df2.to_csv('cluster_using_Elmo-Networks.csv')
